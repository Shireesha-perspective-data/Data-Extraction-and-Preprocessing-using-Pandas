# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("bollywood.csv")

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %% [markdown]
# •	SlNo– Release Data
# •	MovieName – Name of the movie
# •	ReleaseTime – Mentions special time of release. LW (Long Weekend), FS (Festive Season), HS (Holiday Season), N (Normal)
# •	Genre – Genre of the film such as Romance, Thriller, Action, Comedy, etc..
# •	Budget – Movie creation budget
# •	BoxOfficeCollection – Box Office collection
# •	YoutubeViews – Number of views of the YouTube trailers
# •	YoutubeLikes – Number of likes of the YouTube trailers
# •	YoutubeDislikes – Number of dislikes of the YouTube trailers

# %% [markdown]
# # Q:
#       a)How many records are present in the dataset? Print the metadata information of the dataset.

# %%
len(df)
# Out:
# 149

# %%
df.info
# Out:
# <bound method DataFrame.info of      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %% [markdown]
# # Q:
#       b)How many movies got released in each genre? Which genre had highest number of releases? Sort number of releases in each genre in descending order.

# %%
df_movie=df['MovieName']  # here the movieName are taken by the bollywood data
df_movie
# Out:
# 0                         2 States
# 1                     Table No. 21
# 2               Amit Sahni Ki List
# 3                 Rajdhani Express
# 4                     Bobby Jasoos
#                   ...
# 144             Dum Laga Ke Haisha
# 145                           NH10
# 146    Dilliwali Zaalim Girlfriend
# 147                       Hunterrr
# 148                  Kochadaiiyaan
# Name: MovieName, Length: 149, dtype: object

# %%
df['MovieName'].unique()
# Out:
# array(['2 States', 'Table No. 21', 'Amit Sahni Ki List',
#        'Rajdhani Express', 'Bobby Jasoos', 'Citylights', 'Daawat-E-Ishq',
#        'Matru Ki Bijlee Ka Mandola', 'Dedh Ishqiya', 'Gangoobai',
#        'Dishkiyaoon', 'Inkaar', 'Ek Villain', 'Mumbai Mirror',
#        'Entertainment', 'Bandook', 'Race 2', 'Filmistaan',
#        'Finding Fanny', 'Fugly', 'David', 'Gulaab Gang', 'Gunday',
#        'Haider', 'Happy Ending', 'Special 26', 'Happy New Year',
#        'ABCD _ Any Body Can Dance', 'Hate Story 2', 'Hawaa Hawaai',
#        'Heartless', 'Murder 3', 'Heropanti', 'Kai Po Che!', 'Highway',
#        'Zilla Ghaziabad', 'Holiday', 'Humpty Sharma Ki Dulhania',
#        'The Attacks of 26/11', 'Humshakals',
#        'Saheb, Biwi Aur Gangster Returns', 'Jai Ho', 'Khoobsurat', 'Kick',
#        '3G', 'Kill Dil', 'Mere Dad Ki Maruti', 'Jolly LLB',
#        'Koyelaanchal', 'Kya Dilli Kya Lahore', 'Lekar Hum Deewana Dil',
# ...

# %%
df['Genre']
# Out:
# 0        Romance
# 1      Thriller
# 2         Comedy
# 3         Drama
# 4         Comedy
#          ...
# 144       Comedy
# 145     Thriller
# 146       Comedy
# 147       Comedy
# 148       Action
# Name: Genre, Length: 149, dtype: object

# %%
df['Genre'].mode() #here which genre means Genre of the film such as Romance, Thriller, Action, Comedy, etc.. in that which is highest number
# Out:
# 0    Comedy
# dtype: object

# %%
df['Genre'].max()
# Out:
# 'Thriller '

# %%
df['Genre'].value_counts()  # here  movies got released in each genre
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
z=df['Genre'].value_counts()
z.sort_values(ascending=False)
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
#ds=df['Genre'].sort_values(ascending=True)
#ds
#des=df['Genre'].sort_values(ascending=False)#.value_counts()
#des
df['Genre'].sort_values(ascending=False)
# Out:
# 20     Thriller
# 1      Thriller
# 16     Thriller
# 30      Thriller
# 44      Thriller
#          ...
# 120       Drama
# 49        Drama
# 102       Drama
# 40        Drama
# 74        Drama
# Name: Genre, Length: 149, dtype: object

# %% [markdown]
#  # Q:
#        c)How many movies in each genre got released in different release times like long weekend, festive season, etc..

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df['ReleaseTime'].value_counts()
# Out:
# N     99
# HS    18
# FS    17
# LW    15
# Name: ReleaseTime, dtype: int64

# %%
df.groupby(['Genre'])['ReleaseTime'].value_counts()
# Out:
# Genre      ReleaseTime
#  Drama     N              24
#            HS              6
#            FS              4
#            LW              1
# Action     N              12
#            FS              3
#            HS              3
#            LW              3
# Action     N               3
# Comedy     N              23
#            HS              5
#            LW              5
#            FS              3
# Romance    N              15
#            LW              4
#            FS              3
#            HS              3
# Thriller   N              20
#            FS              4
#            HS              1
#            LW              1
# Thriller   N               2
#            LW              1
# Name: ReleaseTime, dtype: int64

# %%
df['ReleaseTime'].unique()
# Out:
# array(['LW', 'N', 'HS', 'FS'], dtype=object)

# %%
r=df['ReleaseTime']
r
# Out:
# 0      LW
# 1       N
# 2       N
# 3       N
# 4       N
#        ..
# 144     N
# 145     N
# 146     N
# 147     N
# 148    HS
# Name: ReleaseTime, Length: 149, dtype: object

# %%
m=df[df['ReleaseTime']=='N']
m
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# 6       7    19-Sep-14                Daawat-E-Ishq           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 141   142     6-Feb-15                    Shamitabh           N     Drama
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
#
# ...

# %%
df_val=df[df['Genre']=='Thriller'] #.value_counts()
df_val['ReleaseTime'].value_counts()
# Out:
# N     20
# FS     4
# HS     1
# LW     1
# Name: ReleaseTime, dtype: int64

# %%
'''Comedy       36
 Drama       35
Thriller     26
Romance      25
Action       21
Thriller      3
 
'''
df_C=df[df['Genre']=='Comedy']
df_C['ReleaseTime'].value_counts()
# Out:
# N     23
# LW     5
# HS     5
# FS     3
# Name: ReleaseTime, dtype: int64

# %%
df_D=df[df['Genre']=='Drama']
df_D['ReleaseTime'].value_counts()
# Out:
# Series([], Name: ReleaseTime, dtype: int64)

# %%
df_R=df[df['Genre']=='Romance']
df_R['ReleaseTime'].value_counts()
# Out:
# N     15
# LW     4
# HS     3
# FS     3
# Name: ReleaseTime, dtype: int64

# %%
df_A=df[df['Genre']=='Action']
df_A['ReleaseTime'].value_counts()
# Out:
# N     12
# HS     3
# LW     3
# FS     3
# Name: ReleaseTime, dtype: int64

# %%
df_A=df[df['Genre']=='Action']
df_A['ReleaseTime'].value_counts()
# Out:
# N     12
# HS     3
# LW     3
# FS     3
# Name: ReleaseTime, dtype: int64

# %%
df.groupby(['Genre'])['ReleaseTime'].value_counts()
# Out:
# Genre      ReleaseTime
#  Drama     N              24
#            HS              6
#            FS              4
#            LW              1
# Action     N              12
#            FS              3
#            HS              3
#            LW              3
# Action     N               3
# Comedy     N              23
#            HS              5
#            LW              5
#            FS              3
# Romance    N              15
#            LW              4
#            FS              3
#            HS              3
# Thriller   N              20
#            FS              4
#            HS              1
#            LW              1
# Thriller   N               2
#            LW              1
# Name: ReleaseTime, dtype: int64

# %% [markdown]
# # Q :
#       d)Which month of the year, maximum number movie releases are seen? (Extract month component from ReleaseDate column)

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
#df[df['Release Date']=='d/-w[A-Z]./-d/']
df[['Release Date','YoutubeViews']].max() # here 9-May-2014 the maximum number of movies release
# Out:
# Release Date    9-May-14
# YoutubeViews    23171067
# dtype: object

# %% [markdown]
# # Q:
#        e)Which month of the year typically sees most releases of high budgeted movies, that is, movies with budget of 25 crore or more?

# %%
df['Budget'].max()
# Out:
# 150

# %%
df[df['Budget']>=25] #& df['Budget']]
# Out:
#      SlNo Release Date                    MovieName ReleaseTime    Genre  \
# 0       1    18-Apr-14                     2 States          LW  Romance
# 6       7    19-Sep-14                Daawat-E-Ishq           N   Comedy
# 7       8    11-Jan-13   Matru Ki Bijlee Ka Mandola           N   Comedy
# 8       9    10-Jan-14                 Dedh Ishqiya          LW   Comedy
# 10     11    28-Mar-14                  Dishkiyaoon           N  Action
# ..    ...          ...                          ...         ...      ...
# 139   140    30-Jan-15                   Hawaizaada           N   Drama
# 141   142     6-Feb-15                    Shamitabh           N   Drama
# 142   143    13-Feb-15                          Roy          FS  Romance
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N   Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS   Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %% [markdown]
# # Q:
#       f)Which are top 10 movies with maximum return on investment (ROI)? Calculate return on investment (ROI) as (BoxOfficeCollection – Budget)/Budget

# %%
df.MovieName.sample(10).max()
# Out:
# 'Shuddh Desi Romance'

# %%
df['BoxOfficeCollection'].mean()
# Out:
# 55.667248322147664

# %%
df['Budget'].mean()
# Out:
# 29.44295302013423

# %%
df[df['Budget']>=29.4429].sample(10)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 92     93     2-Oct-14                    Bang Bang          FS    Action
# 8       9    10-Jan-14                 Dedh Ishqiya          LW    Comedy
# 117   118    23-Aug-13                  Madras Cafe           N  Thriller
# 96     97     2-Oct-13                     Besharam          LW    Comedy
# 68     69     3-May-13           Shootout at Wadala           N  Thriller
# 22     23    14-Feb-14                       Gunday           N    Action
# 26     27    24-Oct-14               Happy New Year          LW    Drama
# 39     40    20-Jun-14                   Humshakals          HS    Comedy
# 102   103    25-Apr-14                      Kaanchi           N    Drama
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 146      32                 12.0       2316047          4289              807
# ...

# %%
#df[(df['BoxOfficeCollection'])-(df['Budget'])]
df_b=df['BoxOfficeCollection']
df_bud=df['Budget']

df_invest=(df_b - df_bud)/df_bud
df_invest
# Out:
# 0      1.888889
# 1      0.200000
# 2     -0.600000
# 3     -0.950000
# 4     -0.400000
#          ...
# 144    1.000000
# 145    1.469231
# 146   -0.625000
# 147    1.378000
# 148   -0.200000
# Length: 149, dtype: float64

# %% [markdown]
# # Q:
#      g)Do the movies have higher ROI if they get released on festive seasons or long weekend? Calculate the average ROI for different release times.

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...
