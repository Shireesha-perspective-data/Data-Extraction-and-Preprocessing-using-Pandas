# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("earthquake.csv",sep=',')

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.tail()
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake  12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake  10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake  79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df.Time
# Out:
# 0        13:44:18
# 1        11:29:49
# 2        18:05:58
# 3        18:49:43
# 4        13:32:50
#            ...
# 23407    08:22:12
# 23408    09:13:47
# 23409    12:38:51
# 23410    22:30:19
# 23411    20:08:28
# Name: Time, Length: 23412, dtype: object

# %%
df.Time
# Out:
# 0        13:44:18
# 1        11:29:49
# 2        18:05:58
# 3        18:49:43
# 4        13:32:50
#            ...
# 23407    08:22:12
# 23408    09:13:47
# 23409    12:38:51
# 23410    22:30:19
# 23411    20:08:28
# Name: Time, Length: 23412, dtype: object

# %%
df["Time"]
# Out:
# 0        13:44:18
# 1        11:29:49
# 2        18:05:58
# 3        18:49:43
# 4        13:32:50
#            ...
# 23407    08:22:12
# 23408    09:13:47
# 23409    12:38:51
# 23410    22:30:19
# 23411    20:08:28
# Name: Time, Length: 23412, dtype: object

# %%
df.shape # It return as how many rows and columns in a given data set
# Out:
# (23412, 21)

# %%
row,cols=df.shape   # It also access the number of row and columns

# %%
print(row)
# Out:
# 23412

# %%
#cols
print(cols)
# Out:
# 21

# %%
df.size  #size of the data set
# Out:
# 491652

# %%
df.sample()  # To Access the any one randomlly selected the data set value
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 13002  04/22/1996  11:27:56    29.797    129.051  Earthquake  196.9
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 13002          NaN                     NaN        5.6            MWC  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 13002                         NaN            NaN                  NaN
#
#        Horizontal Error  Root Mean Square          ID Source Location Source  \
# 13002               NaN               1.0  USP0007GFQ     US              US
#
#       Magnitude Source    Status
# 13002              HRV  Reviewed
#
# [1 rows x 21 columns]

# %%
df.sample(5)  # Here to print the 5 samples randomlly
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 5086   02/20/1979  06:32:32    40.232    143.703  Earthquake   10.0
# 22347  08/20/2014  10:14:16    32.636     47.736  Earthquake   17.7
# 18801  12/22/2007  07:11:08    -2.407    139.067  Earthquake   20.0
# 19823  12/24/2009  00:23:31    42.126    135.008  Earthquake  395.0
# 15371  04/20/2001  19:20:51    -7.560    155.955  Earthquake   10.0
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 5086           NaN                     NaN        6.4             MS  ...
# 22347          3.4                     NaN        5.6            MWB  ...
# 18801          NaN                   280.0        6.2            MWC  ...
# 19823          NaN                     NaN        5.7             MW  ...
# 15371          NaN                   141.0        5.6            MWC  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# ...

# %%
df.sample(random_state=1)  # Here to print the only one value ,it can not change the value
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 15555  09/20/2001  02:01:52   -11.375    115.042  Earthquake   10.0
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 15555          NaN                   216.0        5.6            MWC  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 15555                         NaN            NaN                  NaN
#
#        Horizontal Error  Root Mean Square          ID Source Location Source  \
# 15555               NaN              1.09  USP000APG9     US              US
#
#       Magnitude Source    Status
# 15555              HRV  Reviewed
#
# [1 rows x 21 columns]

# %%
df.sample(10,random_state=1)
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 15555  09/20/2001  02:01:52  -11.3750   115.0420  Earthquake   10.00
# 8994   05/05/1988  22:32:49  -26.6490  -113.6640  Earthquake   10.00
# 19205  10/07/2008  10:00:48   79.8170  -115.4480  Earthquake   10.00
# 9937   04/18/1990  17:06:18    1.2630   122.9840  Earthquake   35.30
# 14760  03/10/2000  16:22:47   -8.7010   106.3790  Earthquake   33.00
# 21916  10/06/2013  21:33:20  -36.7267   -97.4761  Earthquake   10.28
# 21172  02/23/2012  05:08:13  -17.6990   -13.1930  Earthquake   10.00
# 19296  12/10/2008  13:15:34  -12.3370   166.5720  Earthquake   51.00
# 20716  04/05/2011  04:10:07  -17.6620  -178.5950  Earthquake  552.40
# 16866  07/29/2004  13:23:03   12.4450    95.0030  Earthquake   24.10
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 15555          NaN                   216.0        5.6            MWC  ...
# ...

# %%
df.Longitude.unique() # return the unique values in the Longitude column
# Out:
# array([ 145.616 ,  127.352 , -173.972 , ...,  140.4262,  118.6639,
#         141.4103])

# %%
df.Date.unique()
# Out:
# array(['01/02/1965', '01/04/1965', '01/05/1965', ..., '12/28/2016',
#        '12/29/2016', '12/30/2016'], dtype=object)

# %%
len(df.Date.unique())   # the length of the unique values in the Data column
# Out:
# 12401

# %%
df.nunique()  # unique values each column
# Out:
# Date                          12401
# Time                          20472
# Latitude                      20676
# Longitude                     21474
# Type                              4
# Depth                          3485
# Depth Error                     297
# Depth Seismic Stations          736
# Magnitude                        64
# Magnitude Type                   10
# Magnitude Error                 100
# Magnitude Seismic Stations      246
# Azimuthal Gap                  1109
# Horizontal Distance            1448
# Horizontal Error                186
# Root Mean Square                190
# ID                            23412
# Source                           13
# Location Source                  48
# Magnitude Source                 24
# Status                            2
# dtype: int64

# %%
df.isna()  # here it returns the null value is True,otherwise False
# Out:
#         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# 0                        True      False           False  ...
# ...

# %%
df.isna().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# ...

# %%
df.isnull()
# Out:
#         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# 0                        True      False           False  ...
# ...

# %%
df.isnull().mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# ...

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         Date   Time  Latitude  Longitude   Type  Depth  Depth Error  \
# 0      False  False     False      False  False  False         True
# 1      False  False     False      False  False  False         True
# 2      False  False     False      False  False  False         True
# 3      False  False     False      False  False  False         True
# 4      False  False     False      False  False  False         True
# ...      ...    ...       ...        ...    ...    ...          ...
# 23407  False  False     False      False  False  False        False
# 23408  False  False     False      False  False  False        False
# 23409  False  False     False      False  False  False        False
# 23410  False  False     False      False  False  False        False
# 23411  False  False     False      False  False  False        False
#
#        Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# ...

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.nsmallest(1,"Magnitude")
# Out:
#           Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 12  01/29/1965  09:35:30    54.636    161.703  Earthquake   55.0          NaN
#
#     Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 12                     NaN        5.5             MW  ...
#
#     Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 12                         NaN            NaN                  NaN
#
#     Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 12               NaN               NaN  ISCGEM861461  ISCGEM          ISCGEM
#
#    Magnitude Source     Status
# 12           ISCGEM  Automatic
#
# [1 rows x 21 columns]

# %%
df.nlargest(1,"Magnitude")
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 17083  12/26/2004  00:58:53     3.295     95.982  Earthquake   30.0
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 17083          NaN                   601.0        9.1             MW  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 17083                         NaN           22.0                  NaN
#
#        Horizontal Error  Root Mean Square                            ID  \
# 17083               NaN              1.17  OFFICIAL20041226005853450_30
#
#          Source Location Source Magnitude Source    Status
# 17083  OFFICIAL              US         OFFICIAL  Reviewed
#
# [1 rows x 21 columns]

# %%
df.loc[:]
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.loc[::,::]
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.loc[::]
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.loc[43,['Latitude','Longitude']]
# Out:
# Latitude      52.057
# Longitude    174.116
# Name: 43, dtype: object

# %%
df.loc[43,'Latitude']
# Out:
# 52.057

# %%
df.iloc[[0,1,2,3,4],-18] #  here iloc is consider the index values
# Out:
# 0    145.616
# 1    127.352
# 2   -173.972
# 3    -23.557
# 4    126.427
# Name: Longitude, dtype: float64

# %%
df.iloc[:]
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.iloc[1::-4]
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 1                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 1                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 1           ISCGEM  Automatic
#
# [1 rows x 21 columns]

# %%
df.iloc[::-1]  #here the row are descending order
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# ...           ...       ...       ...        ...         ...     ...
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.iloc[::-1,::-1]
# Out:
#           Status Magnitude Source Location Source  Source            ID  \
# 23411   Reviewed               US              US      US    US10007NTD
# 23410   Reviewed               US              US      US    US10007NL0
# 23409   Reviewed               US              US      US    US10007NAF
# 23408   Reviewed               NN              NN      NN    NN00570744
# 23407   Reviewed               NN              NN      NN    NN00570710
# ...          ...              ...             ...     ...           ...
# 4      Automatic           ISCGEM          ISCGEM  ISCGEM  ISCGEM860890
# 3      Automatic           ISCGEM          ISCGEM  ISCGEM  ISCGEM860856
# 2      Automatic           ISCGEM          ISCGEM  ISCGEM  ISCGEM860762
# 1      Automatic           ISCGEM          ISCGEM  ISCGEM  ISCGEM860737
# 0      Automatic           ISCGEM          ISCGEM  ISCGEM  ISCGEM860706
#
#        Root Mean Square  Horizontal Error  Horizontal Distance  Azimuthal Gap  \
# ...
