# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/gapminder.tsv",sep="\t")

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.loc[2,"country"]  #[pattern or row or r , string "" are used column or aattribute in statistics  values]
# Out:
# 'Afghanistan'

# %%
df.loc[[1,2,34,26,367],"country"]
# Out:
# 1        Afghanistan
# 2        Afghanistan
# 34           Algeria
# 26           Algeria
# 367    Cote d'Ivoire
# Name: country, dtype: object

# %%
df.loc[[1,23,45,1234,3,10],["country","lifeExp","year","pop","continent","gdpPercap"]]
# Out:
#           country  lifeExp  year       pop continent     gdpPercap
# 1     Afghanistan   30.332  1957   9240934      Asia    820.853030
# 23        Albania   76.423  2007   3600523    Europe   5937.029526
# 45         Angola   40.963  1997   9875024    Africa   2277.140884
# 1234       Poland   74.670  2002  38625976    Europe  12002.239080
# 3     Afghanistan   34.020  1967  11537966      Asia    836.197138
# 10    Afghanistan   42.129  2002  25268405      Asia    726.734055

# %%
df.iloc[3,5]   #3 	Afghanistan 	Asia 	1967 	34.020 	11537966 	"836.197138" index of 5 is gdpPercap
          #the index means columns i.e 0 index is country ...0,1,2,3,4,5 == country,lifeExp,year,pop,continent,gdpPercap
# Out:
# 836.1971382

# %%
df.loc[2:403:100,["country","gdpPercap","pop","year"]]   # 2:550:189   2+189=191, 191+189=380
#2+100=102; 102+100=202; 202+100=302; 302+100=402  like 2:401:100 here execute only upto 302
# Out:
#             country     gdpPercap       pop  year
# 2       Afghanistan    853.100710  10267083  1962
# 102      Bangladesh    676.981866  93074406  1982
# 202    Burkina Faso   1037.645221  12251209  2002
# 302        Colombia   2492.351109  17009885  1962
# 402  Czech Republic  15377.228550  10303704  1982

# %%
df.loc[3:8,"year"]  #here loc()method to use column in str " " .multi column we want then we take [" "," "," "]
# Out:
# 3    1967
# 4    1972
# 5    1977
# 6    1982
# 7    1987
# 8    1992
# Name: year, dtype: int64

# %%
df.iloc[45::90,2:6]  #column index we are taken
# Out:
#       year  lifeExp       pop     gdpPercap
# 45    1997   40.963   9875024   2277.140884
# 135   1967   45.032   4040665   2586.886053
# 225   1997   56.534  11782962    734.285170
# 315   1967   46.472    217378   1876.029643
# 405   1997   74.010  10300707  16048.514240
# 495   1967   42.189   1820319    468.794970
# 585   1997   58.556  18418288   1005.245812
# 675   1967   69.500  10223422   9326.644670
# 765   1997   78.269   5531387  20896.609240
# 855   1967   64.624    575003  80894.883260
# 945   1997   71.938  20476091  10132.909640
# 1035  1967   38.113   8680909    566.669154
# 1125  1997   51.313   9666252    580.305209
# 1215  1967   56.393  35356600   1814.127430
# 1305  1997   63.306    145608   1339.076036
# 1395  1967   38.977   3428839   1284.733180
# 1485  1997   79.370   7193761  32135.323010
# 1575  1967   54.336  33411317   2826.356387
# 1665  1997   71.096   2826046   7110.667619

# %%
print(df.iloc[1:5,3:6],end=" ")
# Out:
#    lifeExp       pop   gdpPercap
# 1   30.332   9240934  820.853030
# 2   31.997  10267083  853.100710
# 3   34.020  11537966  836.197138
# 4   36.088  13079460  739.981106

# %%
df.loc[1,"country":"pop"]
# Out:
# country      Afghanistan
# continent           Asia
# year                1957
# lifeExp           30.332
# pop              9240934
# Name: 1, dtype: object

# %%
df.loc[1,"pop":"country"]
# Out:
# Series([], Name: 1, dtype: object)

# %%
df.loc[::,"country":"pop"]
# Out:
#           country continent  year  lifeExp       pop
# 0     Afghanistan      Asia  1952   28.801   8425333
# 1     Afghanistan      Asia  1957   30.332   9240934
# 2     Afghanistan      Asia  1962   31.997  10267083
# 3     Afghanistan      Asia  1967   34.020  11537966
# 4     Afghanistan      Asia  1972   36.088  13079460
# ...           ...       ...   ...      ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418
# 1700     Zimbabwe    Africa  1992   60.377  10704340
# 1701     Zimbabwe    Africa  1997   46.809  11404948
# 1702     Zimbabwe    Africa  2002   39.989  11926563
# 1703     Zimbabwe    Africa  2007   43.487  12311143
#
# [1704 rows x 5 columns]

# %%
df.loc[1:4:3,"country":"pop"]
# Out:
#        country continent  year  lifeExp       pop
# 1  Afghanistan      Asia  1957   30.332   9240934
# 4  Afghanistan      Asia  1972   36.088  13079460

# %%
print(df.loc[23:45:23,"country"])
print(df.loc[23:46:23,"country"])
# Out:
# 23    Albania
# Name: country, dtype: object
# 23    Albania
# 46     Angola
# Name: country, dtype: object

# %%
#df.iloc[1:10:2,"country"]  
# above statement ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types
df.iloc[1:10:2,[-0,-4]]   #country 	continent 	year 	lifeExp 	pop
                          #  -0         -4      -3index    -2       -1   here [-0:-5] i.e 0 is start index n-1 =5-1
print(df.iloc[1:10:2,[-0,-1,-4,2,3,-5,5]])  #4-1=3index is year
# Out:
#        country   gdpPercap  year  year  lifeExp continent   gdpPercap
# 1  Afghanistan  820.853030  1957  1957   30.332      Asia  820.853030
# 3  Afghanistan  836.197138  1967  1967   34.020      Asia  836.197138
# 5  Afghanistan  786.113360  1977  1977   38.438      Asia  786.113360
# 7  Afghanistan  852.395945  1987  1987   40.822      Asia  852.395945
# 9  Afghanistan  635.341351  1997  1997   41.763      Asia  635.341351

# %%
df.iloc[1:12:2,-1:-5:-1]   #country(-6) 	continent(-5) 	year(-4) 	lifeExp(-3) 	pop(-2) 	gdpPercap(-1)
# Out:
#      gdpPercap       pop  lifeExp  year
# 1   820.853030   9240934   30.332  1957
# 3   836.197138  11537966   34.020  1967
# 5   786.113360  14880372   38.438  1977
# 7   852.395945  13867957   40.822  1987
# 9   635.341351  22227415   41.763  1997
# 11  974.580338  31889923   43.828  2007

# %%
df.sample(10,random_state=245)  # random_state mean the 10 random values  are not change
# Out:
#              country continent  year  lifeExp       pop     gdpPercap
# 88           Bahrain      Asia  1972   63.300    230800  18268.658390
# 23           Albania    Europe  2007   76.423   3600523   5937.029526
# 399   Czech Republic    Europe  1967   70.380   9835109  11399.444890
# 759           Israel      Asia  1967   70.750   2693585   8393.741404
# 1647         Vietnam      Asia  1967   47.838  39463910    637.123289
# 1673     Yemen, Rep.      Asia  1977   44.175   8403990   1829.765177
# 46            Angola    Africa  2002   41.003  10866106   2773.287312
# 1410    South Africa    Africa  1982   58.161  31140029   8568.266228
# 917       Madagascar    Africa  1977   46.881   8007166   1544.228586
# 516          Finland    Europe  1952   66.550   4090500   6424.519071

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.year # here the attribute of a year  data will be execute
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df.year.unique()  # here  year column  as a unique data will be execute
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
# here we want to 1987 (or any one) data with special data of year 
df[df['year']==1987]  # in 1987 year of data will be execute.
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 7            Afghanistan      Asia  1987   40.822  13867957   852.395945
# 19               Albania    Europe  1987   72.000   3075321  3738.932735
# 31               Algeria    Africa  1987   65.799  23254956  5681.358539
# 43                Angola    Africa  1987   39.906   7874230  2430.208311
# 55             Argentina  Americas  1987   70.774  31620918  9139.671389
# ...                  ...       ...   ...      ...       ...          ...
# 1651             Vietnam      Asia  1987   62.820  62826491   820.799445
# 1663  West Bank and Gaza      Asia  1987   67.046   1691210  5107.197384
# 1675         Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538
# 1687              Zambia    Africa  1987   50.821   7272406  1213.315116
# 1699            Zimbabwe    Africa  1987   62.351   9216418   706.157306
#
# [142 rows x 6 columns]

# %%
# we want to special data of 1987 year of Asia continent data i want 
year_1987=df[df['year']==1987]
year_1987[year_1987['continent']=='Asia']
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 7            Afghanistan      Asia  1987   40.822    13867957    852.395945
# 91               Bahrain      Asia  1987   70.750      454612  18524.024060
# 103           Bangladesh      Asia  1987   52.819   103764241    751.979403
# 223             Cambodia      Asia  1987   53.914     8371791    683.895573
# 295                China      Asia  1987   67.274  1084035000   1378.904018
# 667     Hong Kong, China      Asia  1987   76.200     5584510  20038.472690
# 703                India      Asia  1987   58.553   788000000    976.512676
# 715            Indonesia      Asia  1987   60.137   169276000   1748.356961
# 727                 Iran      Asia  1987   63.040    51889696   6642.881371
# 739                 Iraq      Asia  1987   65.044    16543189  11643.572680
# 763               Israel      Asia  1987   75.600     4203148  17122.479860
# ...

# %%
df[df['country']=='Africa']
# Out:
# Empty DataFrame
# Columns: [country, continent, year, lifeExp, pop, gdpPercap]
# Index: []

# %%
df[df['year']==1987].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_17448/2654054650.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['year']==1987].mean()
# year         1.987000e+03
# lifeExp      6.321261e+01
# pop          3.303857e+07
# gdpPercap    7.900920e+03
# dtype: float64

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
year_1987=df[df['year']==1987]
year_1987[year_1987['continent']=='Asia']
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 7            Afghanistan      Asia  1987   40.822    13867957    852.395945
# 91               Bahrain      Asia  1987   70.750      454612  18524.024060
# 103           Bangladesh      Asia  1987   52.819   103764241    751.979403
# 223             Cambodia      Asia  1987   53.914     8371791    683.895573
# 295                China      Asia  1987   67.274  1084035000   1378.904018
# 667     Hong Kong, China      Asia  1987   76.200     5584510  20038.472690
# 703                India      Asia  1987   58.553   788000000    976.512676
# 715            Indonesia      Asia  1987   60.137   169276000   1748.356961
# 727                 Iran      Asia  1987   63.040    51889696   6642.881371
# 739                 Iraq      Asia  1987   65.044    16543189  11643.572680
# 763               Israel      Asia  1987   75.600     4203148  17122.479860
# ...

# %%
year_1987=df[df['year']==1987]
year_1987[year_1987['continent']=='Asia'].shape
# Out:
# (33, 6)

# %%
year_1987=df[df['year']==1987]
year_1987[year_1987['continent']=='Asia']['lifeExp']
# Out:
# 7       40.822
# 91      70.750
# 103     52.819
# 223     53.914
# 295     67.274
# 667     76.200
# 703     58.553
# 715     60.137
# 727     63.040
# 739     65.044
# 763     75.600
# 799     78.670
# 811     65.869
# 835     70.647
# 847     69.810
# 859     74.174
# 871     67.926
# 943     69.500
# 1003    60.222
# 1051    58.339
# 1075    52.537
# 1159    67.734
# 1171    58.245
# 1219    64.151
# 1315    66.295
# 1363    73.560
# 1435    69.011
# 1495    66.974
# 1507    73.400
# 1531    66.084
# 1651    62.820
# 1663    67.046
# 1675    52.922
# Name: lifeExp, dtype: float64

# %%
year_1987=df[df['year']==1987]
year_1987[year_1987['continent']=='Asia']['lifeExp'].mean()
# Out:
# 64.85118181818181

# %%
df[df['country']=='Singapore']['lifeExp']
# Out:
# 1356    60.396
# 1357    63.179
# 1358    65.798
# 1359    67.946
# 1360    69.521
# 1361    70.795
# 1362    71.760
# 1363    73.560
# 1364    75.788
# 1365    77.158
# 1366    78.770
# 1367    79.972
# Name: lifeExp, dtype: float64

# %%
df[df['country']=='Singapore']['lifeExp'].mean()
# Out:
# 71.22025

# %%
df[df['pop'] >=19067554]#['lifeExp']
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 30        Algeria    Africa  1982   61.368  20033753  5745.160213
# 31        Algeria    Africa  1987   65.799  23254956  5681.358539
# ...           ...       ...   ...      ...       ...          ...
# 1652      Vietnam      Asia  1992   67.662  69940728   989.023149
# 1653      Vietnam      Asia  1997   70.672  76048996  1385.896769
# 1654      Vietnam      Asia  2002   73.017  80908147  1764.456677
# 1655      Vietnam      Asia  2007   74.249  85262356  2441.576404
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
#
# [432 rows x 6 columns]

# %%
df[df['pop']>=19067554][['lifeExp','country','pop']]
# Out:
#       lifeExp      country       pop
# 9      41.763  Afghanistan  22227415
# 10     42.129  Afghanistan  25268405
# 11     43.828  Afghanistan  31889923
# 30     61.368      Algeria  20033753
# 31     65.799      Algeria  23254956
# ...       ...          ...       ...
# 1652   67.662      Vietnam  69940728
# 1653   70.672      Vietnam  76048996
# 1654   73.017      Vietnam  80908147
# 1655   74.249      Vietnam  85262356
# 1679   62.698  Yemen, Rep.  22211743
#
# [432 rows x 3 columns]

# %%
df[df['pop']>=19067554]['lifeExp']
# Out:
# 9       41.763
# 10      42.129
# 11      43.828
# 30      61.368
# 31      65.799
#          ...
# 1652    67.662
# 1653    70.672
# 1654    73.017
# 1655    74.249
# 1679    62.698
# Name: lifeExp, Length: 432, dtype: float64

# %%
pop_=df[df['pop']>=19067554]
pop_['lifeExp'].sort_values(ascending=True)
# Out:
# 504     34.078
# 1044    36.319
# 1128    36.324
# 505     36.667
# 696     37.373
#          ...
# 801     80.690
# 1427    80.941
# 71      81.235
# 802     82.000
# 803     82.603
# Name: lifeExp, Length: 432, dtype: float64

# %%
pop_=df[df['pop']>=19067554]
pop_['lifeExp'].sort_values(ascending=True).index
# Out:
# Int64Index([ 504, 1044, 1128,  505,  696,  708,   96, 1129,   97, 1130,
#             ...
#              778,   70,  779,  251,  539,  801, 1427,   71,  802,  803],
#            dtype='int64', length=432)

# %%
pop_=df[df['pop']>=19067554]
pop_.loc[list(pop_['lifeExp'].sort_values(ascending=True).index),:].iloc[1,:]
# Out:
# country       Myanmar
# continent        Asia
# year             1952
# lifeExp        36.319
# pop          20092996
# gdpPercap       331.0
# Name: 1044, dtype: object

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['lifeExp'] >=65.799
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: lifeExp, Length: 1704, dtype: bool

# %%
life_=df[df['lifeExp']>=65.799]         #['lifeExp']
life_.loc[list(life_['pop'].sort_values(ascending=True).index),:].iloc[4,:]
# Out:
# country          Iceland
# continent         Europe
# year                1972
# lifeExp            74.46
# pop               209275
# gdpPercap    15798.06362
# Name: 688, dtype: object

# %%
'''
by usin read_csv function from the pandas  we are reading csv file
'''
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/scientists.csv")

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
df.shape  # the range of the data
# Out:
# (8, 5)

# %%
df.info() # information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes

# %%
df[['Name','Born']] #to print out the Name attribute and Born attribute from the dataframe
# Out:
#                    Name        Born
# 0     Rosaline Franklin  1920-07-25
# 1        William Gosset  1876-06-13
# 2  Florence Nightingale  1820-05-12
# 3           Marie Curie  1867-11-07
# 4         Rachel Carson  1907-05-27
# 5             John Snow  1813-03-15
# 6           Alan Turing  1912-06-23
# 7          Johann Gauss  1777-04-30

# %%
df['Born']
# Out:
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30
# Name: Born, dtype: object

# %%
# pd.to_datetime(df['Born'],format="%Y-%m-%d")
# df['day_differ']=pd.to_datetime(df['Born'],format="%Y-%m-%d")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 448.0+ bytes

# %%
df['Age']
df['Born']
df['Occupation']
df[['Age','Born','Occupation']]
# Out:
#    Age        Born          Occupation
# 0   37  1920-07-25             Chemist
# 1   61  1876-06-13        Statistician
# 2   90  1820-05-12               Nurse
# 3   66  1867-11-07             Chemist
# 4   56  1907-05-27           Biologist
# 5   45  1813-03-15           Physician
# 6   41  1912-06-23  Computer Scientist
# 7   77  1777-04-30       Mathematician

# %%
type('Born') # Born attribute is which type of data type that y we are using the type method
# Out:
# str

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
'''*  function called to_datetime from the pandas i.e we are calling "to_datetime" function from the pandas
to_datetime fun or method from the pandas the born object is converted to datetime formate.
born object type is converted to datetime formate
* born object type is converted to to_datetime formate
'''
pd.to_datetime(df['Born'],format ="%Y-%m-%d") #here  we use datetime method to connected to pandas ,born colum is a object type ,format parameter is used  
df['born_datetime']=pd.to_datetime(df['Born'],format ="%Y-%m-%d") #
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#   born_datetime
# 0    1920-07-25
# 1    1876-06-13
# 2    1820-05-12
# 3    1867-11-07
# 4    1907-05-27
# 5    1813-03-15
# 6    1912-06-23
# 7    1777-04-30

# %%
df['died_datetime']=pd.to_datetime(df['Died'],format="%Y-%m-%d")  # Died object type is converted to datetime formate
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#   born_datetime died_datetime
# 0    1920-07-25    1958-04-16
# 1    1876-06-13    1937-10-16
# 2    1820-05-12    1910-08-13
# 3    1867-11-07    1934-07-04
# 4    1907-05-27    1964-04-14
# 5    1813-03-15    1858-06-16
# 6    1912-06-23    1954-06-07
# 7    1777-04-30    1855-02-23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           8 non-null      object
#  1   Born           8 non-null      object
#  2   Died           8 non-null      object
#  3   Age            8 non-null      int64
#  4   Occupation     8 non-null      object
#  5   born_datetime  8 non-null      datetime64[ns]
#  6   died_datetime  8 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 576.0+ bytes

# %%
'''
 substracted  from the died_datetime to born_datetime .then we are how many days are we are live
 
'''
df['day_datetime']=df['died_datetime']-df['born_datetime'] # the  died_datetime is substracted to born_datetime

# %%
df
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# ...

# %%
df['Age']
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.shape
# Out:
# (8, 8)

# %%
'''
how to drop the drop the column
'''
df.drop(['Born','Age','Occupation','day_datetime'],axis=1) # to check the row wise the
# Out:
#                    Name        Died born_datetime died_datetime
# 0     Rosaline Franklin  1958-04-16    1920-07-25    1958-04-16
# 1        William Gosset  1937-10-16    1876-06-13    1937-10-16
# 2  Florence Nightingale  1910-08-13    1820-05-12    1910-08-13
# 3           Marie Curie  1934-07-04    1867-11-07    1934-07-04
# 4         Rachel Carson  1964-04-14    1907-05-27    1964-04-14
# 5             John Snow  1858-06-16    1813-03-15    1858-06-16
# 6           Alan Turing  1954-06-07    1912-06-23    1954-06-07
# 7          Johann Gauss  1855-02-23    1777-04-30    1855-02-23

# %%
df.drop(['Age'],axis=1)
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# 6    1912-06-23    1954-06-07   15324 days
# ...

# %%
df.drop(['Age'],axis=1,inplace= True)

# %%
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# 6    1912-06-23    1954-06-07   15324 days
# ...

# %%
df.drop(['Died'],axis=1,inplace= False)
# Out:
#                    Name        Born          Occupation born_datetime  \
# 0     Rosaline Franklin  1920-07-25             Chemist    1920-07-25
# 1        William Gosset  1876-06-13        Statistician    1876-06-13
# 2  Florence Nightingale  1820-05-12               Nurse    1820-05-12
# 3           Marie Curie  1867-11-07             Chemist    1867-11-07
# 4         Rachel Carson  1907-05-27           Biologist    1907-05-27
# 5             John Snow  1813-03-15           Physician    1813-03-15
# 6           Alan Turing  1912-06-23  Computer Scientist    1912-06-23
# 7          Johann Gauss  1777-04-30       Mathematician    1777-04-30
#
#   died_datetime day_datetime
# 0    1958-04-16   13779 days
# 1    1937-10-16   22404 days
# 2    1910-08-13   32964 days
# 3    1934-07-04   24345 days
# 4    1964-04-14   20777 days
# 5    1858-06-16   16529 days
# 6    1954-06-07   15324 days
# 7    1855-02-23   28422 days

# %%
'''
how to save the updated dataframe .to add the data to the dataframe
'''

df.to_csv("New_Scientist_data")

# %%
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# 6    1912-06-23    1954-06-07   15324 days
# ...

# %%
df.to_csv("New_Scientist_data-info.csv")

# %%
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# 6    1912-06-23    1954-06-07   15324 days
# ...

# %%
'''
to_csv
to_sql
to_dict
to_json
.......
'''
type('to_csv')
# Out:
# str

# %%
type('to_sql')
# Out:
# str

# %%
df
# Out:
#                    Name        Born        Died          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16             Chemist
# 1        William Gosset  1876-06-13  1937-10-16        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14           Biologist
# 5             John Snow  1813-03-15  1858-06-16           Physician
# 6           Alan Turing  1912-06-23  1954-06-07  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23       Mathematician
#
#   born_datetime died_datetime day_datetime
# 0    1920-07-25    1958-04-16   13779 days
# 1    1876-06-13    1937-10-16   22404 days
# 2    1820-05-12    1910-08-13   32964 days
# 3    1867-11-07    1934-07-04   24345 days
# 4    1907-05-27    1964-04-14   20777 days
# 5    1813-03-15    1858-06-16   16529 days
# 6    1912-06-23    1954-06-07   15324 days
# ...

# %%
df['day_datetime']
# Out:
# 0   13779 days
# 1   22404 days
# 2   32964 days
# 3   24345 days
# 4   20777 days
# 5   16529 days
# 6   15324 days
# 7   28422 days
# Name: day_datetime, dtype: timedelta64[ns]

# %% [markdown]
# ##  Data visualization is as much a part of the data processing step..It is much easier to compare values when they are plotted than numeric values.By visualizing data we are able to get better understand of the data.visualization  can find some hidden pattern and in-depth meaning in data.
# (data visualization means the data processing is very easy and easy to compare the values when they are plotted numeric
# values,and also to find the hidden pattern and in-depth meaning in data.data visualization main (use)theam is it  very easy to understand by visable data)
#
# there are 3 types/ways(libraries) we can gererate visualizatiion :
# 1. pandas to generate  visualization
# 2. matplotlib.pyplot (generates interactive visualization)
# 3. seaboorn (more control on the graphs)
# '''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
day_datetime=df['day_datetime']
plt.plot(day_datetime ,color='indigo');

# %%
plt.plot(day_datetime ,color='r');
