# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q:
#       Q.How much each value of total_bill is far from it's mean(average)?

# %%
df_=df['total_bill'].mean()

# %%
df_
# Out:
# 19.785942622950824

# %%
df_1=df['tip']

# %%
df_1
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df_eachv=(df_)-(df_1)
# fig=plt.figure(figsize=(5,5))
# axes1=fig.add_subplot(1,1,1)
# axes1.hist([df_eachv],color="blue")
df_eachv
# Out:
# 0      18.775943
# 1      18.125943
# 2      16.285943
# 3      16.475943
# 4      16.175943
#          ...
# 239    13.865943
# 240    17.785943
# 241    17.785943
# 242    18.035943
# 243    16.785943
# Name: tip, Length: 244, dtype: float64

# %%
df['total_bill'].mean()-df['total_bill'].unique()  # to substated to the 'total_bill'mean to 'total_bill' each value
# Out:
# array([ 2.79594262e+00,  9.44594262e+00, -1.22405738e+00, -3.89405738e+00,
#        -4.80405738e+00, -5.50405738e+00,  1.10159426e+01, -7.09405738e+00,
#         4.74594262e+00,  5.00594262e+00,  9.51594262e+00, -1.54740574e+01,
#         4.36594262e+00,  1.35594262e+00,  4.95594262e+00, -1.79405738e+00,
#         9.45594262e+00,  3.49594262e+00,  2.81594262e+00, -8.64057377e-01,
#         1.86594262e+00, -5.04057377e-01,  4.01594262e+00, -1.96340574e+01,
#        -3.40573770e-02,  1.97594262e+00,  6.41594262e+00,  7.09594262e+00,
#        -1.91405738e+00,  1.35942623e-01,  1.02359426e+01,  1.43594262e+00,
#         4.72594262e+00, -9.04057377e-01,  2.00594262e+00, -4.27405738e+00,
#         3.47594262e+00,  2.85594262e+00,  1.09594262e+00, -1.14840574e+01,
#         3.74594262e+00,  2.32594262e+00,  5.84594262e+00,  1.01059426e+01,
#        -1.06140574e+01,  1.49594262e+00, -2.44405738e+00, -1.26140574e+01,
# ...

# %% [markdown]
# # Q:
#      Q. Can you take random sample of 50 observations without changing its state from this data?

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 213       13.27  2.50  Female    Yes   Sat  Dinner     2
# 40        16.04  2.24    Male     No   Sat  Dinner     3
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1

# %%
df.sample(50,random_state=2) #50 random sample without change values;
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 54        25.56  4.34    Male     No   Sun  Dinner     4
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 113       23.95  2.55    Male     No   Sun  Dinner     2
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 53         9.94  1.56    Male     No   Sun  Dinner     2
# 65        20.08  3.15    Male     No   Sat  Dinner     3
# 157       25.00  3.75  Female     No   Sun  Dinner     4
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 64        17.59  2.64    Male     No   Sat  Dinner     3
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 71        17.07  3.00  Female     No   Sat  Dinner     3
# 30         9.55  1.45    Male     No   Sat  Dinner     2
# ...

# %%
df.sample(50,random_state=2)['time'].value_counts()#.mode()...here mostly preferred for Dinner
# Out:
# Dinner    36
# Lunch     14
# Name: time, dtype: int64

# %% [markdown]
# # Q:
#      Q. Randomly pick 10 observations of total_bill with certain random state and return its highest total bill value. Repeat the process for 10 times and find its average value.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'].sample(10,random_state=2).max() #here 10 random sample is taken # the highest total_bill is 48.33
# Out:
# 48.33

# %%
df['total_bill'].sample(10,random_state=2).value_counts()
# Out:
# 34.83    1
# 25.56    1
# 8.52     1
# 16.32    1
# 23.95    1
# 34.30    1
# 9.94     1
# 20.08    1
# 25.00    1
# 48.33    1
# Name: total_bill, dtype: int64

# %%
df['total_bill'].sample(10,random_state=2).mean()
# Out:
# 24.683

# %%
df['total_bill'].sample(10,random_state=2)
# Out:
# 85     34.83
# 54     25.56
# 126     8.52
# 93     16.32
# 113    23.95
# 141    34.30
# 53      9.94
# 65     20.08
# 157    25.00
# 212    48.33
# Name: total_bill, dtype: float64

# %%
z=df['total_bill'].sample(10,random_state=2)
max(z)  #48.33
for i in z:
    print(i)
sum(z)/len(z)
# Out:
# 34.83
# 25.56
# 8.52
# 16.32
# 23.95
# 34.3
# 9.94
# 20.08
# 25.0
# 48.33
# 24.683

# %% [markdown]
# # Q:
#        Q. Create the synthetic data for total bill and tip with size of 244. Write code to generate values in between $50 and $100 for total_bill AND tip in between $10 and $20. Plot the newly generated data to see if these two new variables are correlated? and discuss the same.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['new_data']=df['total_bill']
df['new_tipc']=df['tip']
df['new_data']
#df['new_tipc']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: new_data, Length: 244, dtype: float64

# %%
df['new_data']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: new_data, Length: 244, dtype: float64

# %% [markdown]
# # Q:
#       Q. Identify the data where total_bill and tip values are having at least $10 difference.

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df['total_bill']-df['tip'] # the difference of total_bill and tip
# Out:
# 0      15.98
# 1       8.68
# 2      17.51
# 3      20.37
# 4      20.98
#        ...
# 239    23.11
# 240    25.18
# 241    20.67
# 242    16.07
# 243    15.78
# Length: 244, dtype: float64

# %%
df['total_bill']-df['tip'].value_counts()
# Out:
# 0.00       NaN
# 1.00      6.34
# 1.01       NaN
# 1.10       NaN
# 1.17       NaN
#           ...
# 239.00     NaN
# 240.00     NaN
# 241.00     NaN
# 242.00     NaN
# 243.00     NaN
# Length: 359, dtype: float64

# %%
df['New_amount']=df['total_bill']-df['tip']
print(df[df['New_amount']==10])
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size, new_data, new_tipc, New_amount]
# Index: []

# %% [markdown]
# # Q:
#        Q. Randomly pick a total bill value from $0-$10, $11-$20, $21-$30, $31-$40 and $41-$50 and return the highest among the list. And repeat the process for at least 5 times and Identify which are closest values.

# %%
df['total_bill'].sample(10)      #,random_state=2)
# Out:
# 107    25.21
# 132    11.17
# 186    20.90
# 240    27.18
# 144    16.43
# 61     13.81
# 12     15.42
# 212    48.33
# 111     7.25
# 136    10.33
# Name: total_bill, dtype: float64

# %%
df['total_bill'].sample(10).max()#.value_counts()
# Out:
# 45.35

# %%
df['total_bill'].sample(10).value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 117    10.65
# 28     21.70
# 157    25.00
# 23     39.42
# 10     10.27
# 13     18.43
# 201    12.74
# 107    25.21
# 46     22.23
# 129    22.82
# Name: total_bill, dtype: float64>

# %%
df['total_bill'].sample(5).value_counts()
# Out:
# 14.48    1
# 34.83    1
# 11.38    1
# 25.28    1
# 14.15    1
# Name: total_bill, dtype: int64

# %%
df_l=df[df['total_bill']>0]
df_1[df_l['total_bill']<10]
# Out:
# 6      2.00
# 30     1.45
# 43     1.32
# 53     1.56
# 67     1.00
# 92     1.00
# 111    1.00
# 126    1.48
# 135    1.25
# 145    1.50
# 148    1.73
# 149    2.00
# 172    5.15
# 178    4.00
# 195    1.44
# 218    1.44
# 222    1.92
# Name: tip, dtype: float64

# %%
df_l=df[df['total_bill']>0]
df_1[df_l['total_bill']<10].max()
# Out:
# 5.15

# %%
df_2=df[df['total_bill']>11]
df_2[df_2['total_bill']<20].max()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9656/3163953505.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2[df_2['total_bill']<20].max()
# total_bill    19.82
# tip            4.30
# size           4.00
# new_data      19.82
# new_tipc       4.30
# New_amount    17.77
# dtype: float64

# %%
df_3=df[df['total_bill']>21]
df_3[df_3['total_bill']<30].max()        #.shape:=(51, 10)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9656/1199436080.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_3[df_3['total_bill']<30].max()        #.shape:=(51, 10)
# total_bill    29.93
# tip            6.50
# size           6.00
# new_data      29.93
# new_tipc       6.50
# New_amount    26.50
# dtype: float64

# %%
df_4=df[df['total_bill']>31]
df_4[df_4['total_bill']<40].max()     #.shape:=(51, 10)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9656/277932429.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_4[df_4['total_bill']<40].max()     #.shape:=(51, 10)
# total_bill    39.42
# tip            7.58
# size           6.00
# new_data      39.42
# new_tipc       7.58
# New_amount    35.73
# dtype: float64

# %%
df_5=df[df['total_bill']>41]
df_5[df_5['total_bill']<50].max()      #.shape := (7, 10)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9656/1363539953.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_5[df_5['total_bill']<50].max()      #.shape := (7, 10)
# total_bill    48.33
# tip            9.00
# size           6.00
# new_data      48.33
# new_tipc       9.00
# New_amount    43.17
# dtype: float64

# %%
df_6=df[df['total_bill']>51]
df_6[df_6['total_bill']<60].max()    #.shape:= (0, 10)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9656/9105896.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_6[df_6['total_bill']<60].max()    #.shape:= (0, 10)
# total_bill   NaN
# tip          NaN
# size         NaN
# new_data     NaN
# new_tipc     NaN
# New_amount   NaN
# dtype: float64

# %% [markdown]
# # Q:
#      Q. Make a group (cluster) of total bills data from the random sample of 20 observations and find the list of closest values of your choice value.

# %%
df_data=df['total_bill'].sample(20)
df_data
# Out:
# 111     7.25
# 152    17.26
# 34     17.78
# 203    16.40
# 128    11.38
# 136    10.33
# 73     25.28
# 39     31.27
# 83     32.68
# 52     34.81
# 218     7.74
# 177    14.48
# 211    25.89
# 31     18.35
# 133    12.26
# 241    22.67
# 163    13.81
# 24     19.82
# 141    34.30
# 182    45.35
# Name: total_bill, dtype: float64

# %%
df_data=df['total_bill'].sample(20)
df_data
# sns.scatterplot(df.total_bill,df.tip)
# Out:
# 138    16.00
# 92      5.75
# 159    16.49
# 6       8.77
# 205    16.47
# 203    16.40
# 94     22.75
# 25     17.81
# 61     13.81
# 93     16.32
# 111     7.25
# 154    19.77
# 123    15.95
# 141    34.30
# 127    14.52
# 26     13.37
# 220    12.16
# 7      26.88
# 79     17.29
# 178     9.60
# Name: total_bill, dtype: float64

# %% [markdown]
# # Q:
#       Q. Discuss your ideology and critics of why female has less smoking data compared to male?

# %%
r=df[df['smoker']=='Yes']
R=r[r['sex']=='Female']  #the female smokers are 33
len(R)
# Out:
# 33

# %%
m=df[df['smoker']=='Yes']
P=m[m['sex']=='Male']  # the female smokers are less than the male smokers
len(P)
# Out:
# 60

# %% [markdown]
# # Q:
#       Q. Randomly pick a record from this dataset and return its Gender with total bill and tip values. Repeat the process for at least for 5 times and return highest among them.

# %%
#df['total_bill']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_data  new_tipc  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     16.99      1.01
# 1         10.34  1.66    Male     No   Sun  Dinner     3     10.34      1.66
# 2         21.01  3.50    Male     No   Sun  Dinner     3     21.01      3.50
# 3         23.68  3.31    Male     No   Sun  Dinner     2     23.68      3.31
# 4         24.59  3.61  Female     No   Sun  Dinner     4     24.59      3.61
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     29.03      5.92
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     27.18      2.00
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     22.67      2.00
# 242       17.82  1.75    Male     No   Sat  Dinner     2     17.82      1.75
# 243       18.78  3.00  Female     No  Thur  Dinner     2     18.78      3.00
#
#      New_amount
# 0         15.98
# ...

# %%
df[df['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size  new_data  new_tipc  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     16.99      1.01
# 4         24.59  3.61  Female     No   Sun  Dinner     4     24.59      3.61
# 11        35.26  5.00  Female     No   Sun  Dinner     4     35.26      5.00
# 14        14.83  3.02  Female     No   Sun  Dinner     2     14.83      3.02
# 16        10.33  1.67  Female     No   Sun  Dinner     3     10.33      1.67
# ..          ...   ...     ...    ...   ...     ...   ...       ...       ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2     10.09      2.00
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2     22.12      2.88
# 238       35.83  4.67  Female     No   Sat  Dinner     3     35.83      4.67
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     27.18      2.00
# 243       18.78  3.00  Female     No  Thur  Dinner     2     18.78      3.00
#
#      New_amount
# 0         15.98
# ...

# %%
sns.scatterplot(df.total_bill,df.sex,hue=df.tip);#sns.scatterplot(df.total_bill,df.sex,hue=df.tip).value_counts()not soluthen AxesSubplot
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
