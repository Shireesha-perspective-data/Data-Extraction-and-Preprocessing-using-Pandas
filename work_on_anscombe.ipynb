# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
''' we are accessing the 'anscombe' from  the seaborn library by using load_dataset function
anscombe is a dataset function
'''
df=sns.load_dataset("anscombe")# we are accessing the 'ascombe' from  the seaborn library by using load_dataset function

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
len(df)
# Out:
# 44

# %%
dataset_1=df[df['dataset']=='I']   # we are acces the data from the dataset

# %%
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
df[df['dataset']=='I']
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
df['dataset'].value_counts()
# Out:
# I      11
# II     11
# III    11
# IV     11
# Name: dataset, dtype: int64

# %%
x=df['x']
y=df['y']

# %%
x
# Out:
# 0     10.0
# 1      8.0
# 2     13.0
# 3      9.0
# 4     11.0
# 5     14.0
# 6      6.0
# 7      4.0
# 8     12.0
# 9      7.0
# 10     5.0
# 11    10.0
# 12     8.0
# 13    13.0
# 14     9.0
# 15    11.0
# 16    14.0
# 17     6.0
# 18     4.0
# 19    12.0
# 20     7.0
# 21     5.0
# 22    10.0
# 23     8.0
# 24    13.0
# 25     9.0
# 26    11.0
# 27    14.0
# 28     6.0
# 29     4.0
# 30    12.0
# 31     7.0
# 32     5.0
# 33     8.0
# 34     8.0
# 35     8.0
# 36     8.0
# 37     8.0
# 38     8.0
# 39     8.0
# 40    19.0
# 41     8.0
# 42     8.0
# 43     8.0
# Name: x, dtype: float64

# %%
plt.figure(figsize=(6,5))
axes=sns.barplot(x='x',y='y',data=df);
axes.set_title('DataSet',size=25,color='blue')
# Out:
# Text(0.5, 1.0, 'DataSet')
