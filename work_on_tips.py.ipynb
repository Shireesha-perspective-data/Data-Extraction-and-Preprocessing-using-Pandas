# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
'''
scatter plot is used to visualize the relationship between two variables.as points on a two dimensional grid
we are going to use a data set that is already included within the seaborn library ('tips'),but we can also use 
any csv file and import it using pandas.
here seaborn contain a utility function called low dataset and we can give one of the predefined data sets("tips")that
are included with seaborn. tips data like as iris and ect.
'''
tips=sns.load_dataset("tips") #

# %%
tips   #returns the dataframe  in pandas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['size']==2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [156 rows x 7 columns]

# %%
tips_size2=tips.loc[3,'size']

# %%
tips_size2
# Out:
# 2

# %%
tips_size3=tips.loc[2,'size']

# %%
tips_size3
# Out:
# 3

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_index=tips.iloc[4,-2]

# %%
tips_index
# Out:
# 'Dinner'

# %%
tips.sex
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
tips['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sns.set_style('whitegrid')
fig=plt.figure(figsize=(8,4))
axes1=fig.add_subplot(1,1,1)
axes1.set_facecolor('lavender')
axes1.scatter(tips['total_bill'],tips['tip'],color=('blue'))
axes1.set_title("scatter plot of Total bill",size=30,style='italic')
axes1.set_xlabel("Total bill",size=20)
axes1.set_ylabel("Tip",size=20)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/541960091.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'],color="r")
axes1.set_xlabel("total_bill")
axes1.set_ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.sample(5)   #here 5 random data(values) is taken
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 195        7.56  1.44    Male     No  Thur   Lunch     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 156       48.17  5.00    Male     No   Sun  Dinner     6

# %% [markdown]
# '''
# [1  10]->infinite
# continuous variable:- infinite number of possibilities ; here tips are infinite number of possibilities
#    Discreate variable :- set of (or) finite number of possibilities ;male and female ,trancegender set/finite possibilities
# Signature:
# =========
# tips.sample(
#     n=None,
#     frac: 'float | None' = None,
#     replace: 'bool_t' = False,
#     weights=None,
#     random_state=None,
#     axis: 'Axis | None' = None,
#     ignore_index: 'bool_t' = False,
# ) -> 'FrameOrSeries'  '''

# %%
tips.sample(5,random_state=2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 54        25.56  4.34    Male     No   Sun  Dinner     4
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 113       23.95  2.55    Male     No   Sun  Dinner     2

# %%
tips.sample(5) # here sample 5 data are changed every execution is changed
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 69        15.01  2.09    Male    Yes  Sat  Dinner     2
# 45        18.29  3.00    Male     No  Sun  Dinner     2
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 59        48.27  6.73    Male     No  Sat  Dinner     4
# 41        17.46  2.54    Male     No  Sun  Dinner     2

# %%
tips.sample(random_state=89) #here only one(anyone) type of  data is execute not change
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 121       13.42  1.68  Female     No  Thur  Lunch     2

# %%
tips.sample(5,random_state=9)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# 134       18.26  3.25  Female     No  Thur   Lunch     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 156       48.17  5.00    Male     No   Sun  Dinner     6

# %%
tips.iloc[4,-1]    # row ,column is must be index form means -1,-2,-3,-4..here -1 is the 'size'
# Out:
# 4

# %%
tips.loc[3,'size']  # 3 row and size attribute value is 2;loc is used to row(int),column(string form)
# Out:
# 2

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
'''
"scatter plots" are used when a continuous variable is plotted against anether continous
==============
'''
tips['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
len(tips['smoker'])
# Out:
# 244

# %%
tips['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
tips[tips['size']==2]  # here size is 3 data only visable
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [156 rows x 7 columns]

# %%
tips[tips['smoker']=='No']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
tips_n=tips[tips['smoker']=='No']

# %%
tips_n   #not smoker in dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
len(tips)
# Out:
# 244

# %% [markdown]
# # overal not smoking is 151; 244 Toatal dataframe  ; smokers is 93
#
#  # female's are 87,male is 157

# %%
len(tips_n)   # not smoking is 151; 244 Toatal dataframe  ; smokers is 93
# Out:
# 151

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips_female_sex=tips[tips['sex']=="Female"]

# %%
tips_female_sex
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
len(tips_female_sex)
# Out:
# 87

# %%
tips_Males=tips[tips['sex']=="Male"]

# %%
tips_Males
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
len(tips_Males)
# Out:
# 157

# %%
tips.smoker.unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['smoker']=="No"]  #not drink
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
tips['smoker']=='No'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240    False
# 241    False
# 242     True
# 243     True
# Name: smoker, Length: 244, dtype: bool

# %%
tips_Nosmoker=tips[tips['smoker']=='No']   # not smoke

# %%
tips_Nosmoker  #[tips_Nosmoker['Female']=="Yes"]  #=tips[tips['smoker']=="No"]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
tips['smoker']=="Yes"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240     True
# 241     True
# 242    False
# 243    False
# Name: smoker, Length: 244, dtype: bool

# %%
tips_yes=tips[tips['smoker']=="Yes"]
tips_fe=tips_yes[tips_yes['sex']=="Female"]
tips_day=tips_fe[tips_fe['time']=="Dinner"]
tips_tip=tips_day[tips_day['day']=="Fri"]
tips_tip[tips_tip['tip']==3]
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 101       15.38  3.0  Female    Yes  Fri  Dinner     2

# %%
tips_No=tips[tips['smoker']=="No"]
tips_male=tips_No[tips_No['sex']=="Male"]
tips_time=tips_male[tips_male['time']=="Dinner"]
tips_day=tips_time[tips_time['day']=="Sat"]
tips_day[tips_day['tip']==5]
# Out:
#     total_bill  tip   sex smoker  day    time  size
# 39       31.27  5.0  Male     No  Sat  Dinner     3

# %%
tips[tips['smoker']=="Yes"]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
tips[tips['sex']=="Female"]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips_M=tips[tips['sex']=="Male"]
tips_M[tips_M["tip"]==5]
# Out:
#      total_bill  tip   sex smoker   day    time  size
# 39        31.27  5.0  Male     No   Sat  Dinner     3
# 46        22.23  5.0  Male     No   Sun  Dinner     2
# 83        32.68  5.0  Male    Yes  Thur   Lunch     2
# 142       41.19  5.0  Male     No  Thur   Lunch     5
# 156       48.17  5.0  Male     No   Sun  Dinner     6
# 185       20.69  5.0  Male     No   Sun  Dinner     5

# %%
tips_female_smo=tips[tips['sex']=="Female"]

# %%
tips_female_smo                #len(female)=151; male=93
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
len(tips['sex']=='Female')
# Out:
# 244

# %%
tips[tips['smoker']=="No"]  #not drink
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
tips_female_smo=tips[tips['sex']=="Female"]
tips_smo_yes=tips_female_smo[tips_female_smo['smoker']=="Yes"]
tips_smo_yes[tips_smo_yes['size']==3]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3

# %%
tips_data=tips[tips['smoker']=="Yes"]
tips_data[tips_data['size']==4]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4
# 63        18.29  3.76    Male    Yes   Sat  Dinner     4
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4

# %%
tips['day']
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_friday=tips[tips['day']=='Fri']

# %%
tips_friday
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2
# 99        12.46  1.50    Male     No  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# ...

# %%
len(tips_friday)
# Out:
# 19

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips[tips['sex']=="Female"]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %% [markdown]
# # 1.what is the percentage of active smoker in the given sample dataset?

# %%
No_smoker=tips[tips['smoker']=='No']  #not smoking males and females are 151

# %%
No_smoker
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [151 rows x 7 columns]

# %%
len(No_smoker)
# Out:
# 151

# %%
tips_active_smo=tips[tips['smoker']=='Yes']

# %%
tips_active_smo
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
len(tips_active_smo)/244%100 #len 93/244x100 ;active_smo/total dataset %(per)100
# Out:
# 0.38114754098360654

# %%
len(No_smoker)/244%100     # inactive smoker in given dataset .there are 151            #tips_inactive_smo/no_smoker
# Out:
# 0.6188524590163934

# %% [markdown]
# # 2.which gender has mostly occupied space when the table size 3;
#     male are mostly ocuupied which is 50.81; females are 44.3

# %%
tips      #total gender is 38 with size 3 only
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['size']==3
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: size, Length: 244, dtype: bool

# %%
tips[tips['size']==3]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 16        10.33   1.67  Female     No   Sun  Dinner     3
# 17        16.29   3.71    Male     No   Sun  Dinner     3
# 18        16.97   3.50  Female     No   Sun  Dinner     3
# 19        20.65   3.35    Male     No   Sat  Dinner     3
# 35        24.06   3.60    Male     No   Sat  Dinner     3
# 36        16.31   2.00    Male     No   Sat  Dinner     3
# 37        16.93   3.07  Female     No   Sat  Dinner     3
# 38        18.69   2.31    Male     No   Sat  Dinner     3
# 39        31.27   5.00    Male     No   Sat  Dinner     3
# 40        16.04   2.24    Male     No   Sat  Dinner     3
# 48        28.55   2.05    Male     No   Sun  Dinner     3
# 64        17.59   2.64    Male     No   Sat  Dinner     3
# 65        20.08   3.15    Male     No   Sat  Dinner     3
# ...

# %%
tips_size3=tips[tips['size']==3]

# %%
len(tips_size3)
# Out:
# 38

# %%
tips['sex']=='Female'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
tips[tips['sex']=='Female']   #here we want to female size is 3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips_female=tips[tips['sex']=='Female']
tips_female[tips_female['size']==3]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 37        16.93  3.07  Female     No   Sat  Dinner     3
# 71        17.07  3.00  Female     No   Sat  Dinner     3
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 114       25.71  4.00  Female     No   Sun  Dinner     3
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 162       16.21  2.00  Female     No   Sun  Dinner     3
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 238       35.83  4.67  Female     No   Sat  Dinner     3

# %%
tips_females=tips[tips['sex']=='Female']
tips_size_fe=[tips_females[tips_females['size']==3]]

# %%
tips_size_fe
# Out:
# [     total_bill   tip     sex smoker   day    time  size
#  16        10.33  1.67  Female     No   Sun  Dinner     3
#  18        16.97  3.50  Female     No   Sun  Dinner     3
#  37        16.93  3.07  Female     No   Sat  Dinner     3
#  71        17.07  3.00  Female     No   Sat  Dinner     3
#  102       44.30  2.50  Female    Yes   Sat  Dinner     3
#  114       25.71  4.00  Female     No   Sun  Dinner     3
#  146       18.64  1.36  Female     No  Thur   Lunch     3
#  162       16.21  2.00  Female     No   Sun  Dinner     3
#  186       20.90  3.50  Female    Yes   Sun  Dinner     3
#  188       18.15  3.50  Female    Yes   Sun  Dinner     3
#  205       16.47  3.23  Female    Yes  Thur   Lunch     3
#  214       28.17  6.50  Female    Yes   Sat  Dinner     3
#  223       15.98  3.00  Female     No   Fri   Lunch     3
#  238       35.83  4.67  Female     No   Sat  Dinner     3]

# %%
len(tips_size_fe)
# Out:
# 1

# %%
tips_=tips[tips['sex']=='Female']
tips_['total_bill'].min()
# Out:
# 3.07

# %%
tips_=tips[tips['sex']=='Female']
tips_['total_bill'].max()
# Out:
# 44.3

# %%
plt.plot(tips['size']==3,color='b',marker='*',ms=15);

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
len(tips)
# Out:
# 244

# %%
tips_fe=tips[tips['size']==3]
tips_fe.sex.mode()
# Out:
# 0    Male
# Name: sex, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
fem_s=tips[tips['sex']=='Male']
fem_s['total_bill'].max()
#type(fem_s)
# Out:
# 50.81

# %%
tips_mal=tips[tips['sex']=='Female']
tips_mal['total_bill'].max()
# Out:
# 44.3

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Q:
#     Q:what is difference amount of data percentage with respect to sex ? and how much higher in compare to opposite sex?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_=tips[tips['sex']=='Female'].shape[0]/tips.shape[0]*100   # length of female percentage

# %%
tips_
# Out:
# 35.65573770491803

# %%
tips_m=tips[tips['sex']=='Male'].shape[0]/tips.shape[0]*100   # length of male percentage

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
157/244*100  # the total number males by total values(dataset) *100   ' total number of values is 244'
# Out:
# 64.34426229508196

# %%
87/244*100   # number  of females by total number of values * 100
# Out:
# 35.65573770491803

# %%
x=tips[tips['sex']=='Female']  
len(x)
#female_len
# Out:
# 87

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
len(tips_Males)
# Out:
# 157

# %%
64.34426229-35.6557377  #female percentage substracted by male percentage 'male=64.34;female=35.65'
# Out:
# 28.68852459

# %% [markdown]
# # Q:
#    Q:which gender has  offered most valuable tips when tip value is in between 10$ and 20$ dollers

# %%
tips  # female has most valuable tips(4.3) are given in b/w 10 to 20
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
x=tips[tips['sex']=='Female']

# %%
len(x)  #total dataset females are 87 ;males are 157
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
plt.plot(tips['total_bill'],ms='10',marker='*');
plt.plot(tips['tip'],color='r',ms='10',marker='o');
plt.title("tips on total_bill data")
plt.xlabel("total_biil")
plt.ylabel("tips")
plt.legend(['total_bill','tips'])
fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'],color='black')   #=='Male',color='black')
axes1.set_title("dataframe")
axes1.set_xlabel("total bill")
axes1.set_ylabel("tip data")
axes1.legend('total_bill');
#axes1.set_legend(['total_bill','tips'],[1,2])
#fig()

# %%
#val=tips[tips['total_bill']>10,tips['total_bill']<20]
tips_bill=tips[tips['total_bill']>10] #, tips['total_bill']<20]
[tips_bill[tips_bill['total_bill']<20]]
# Out:
# [     total_bill   tip     sex smoker   day    time  size
#  0         16.99  1.01  Female     No   Sun  Dinner     2
#  1         10.34  1.66    Male     No   Sun  Dinner     3
#  8         15.04  1.96    Male     No   Sun  Dinner     2
#  9         14.78  3.23    Male     No   Sun  Dinner     2
#  10        10.27  1.71    Male     No   Sun  Dinner     2
#  ..          ...   ...     ...    ...   ...     ...   ...
#  234       15.53  3.00    Male    Yes   Sat  Dinner     2
#  235       10.07  1.25    Male     No   Sat  Dinner     2
#  236       12.60  1.00    Male    Yes   Sat  Dinner     2
#  242       17.82  1.75    Male     No   Sat  Dinner     2
#  243       18.78  3.00  Female     No  Thur  Dinner     2
#
#  [130 rows x 7 columns]]

# %%
tips_bill=tips[tips['total_bill']>10] #, tips['total_bill']<20]
tips_bill=[tips_bill[tips_bill['total_bill']<20]]
tips_bill
# Out:
# [     total_bill   tip     sex smoker   day    time  size
#  0         16.99  1.01  Female     No   Sun  Dinner     2
#  1         10.34  1.66    Male     No   Sun  Dinner     3
#  8         15.04  1.96    Male     No   Sun  Dinner     2
#  9         14.78  3.23    Male     No   Sun  Dinner     2
#  10        10.27  1.71    Male     No   Sun  Dinner     2
#  ..          ...   ...     ...    ...   ...     ...   ...
#  234       15.53  3.00    Male    Yes   Sat  Dinner     2
#  235       10.07  1.25    Male     No   Sat  Dinner     2
#  236       12.60  1.00    Male    Yes   Sat  Dinner     2
#  242       17.82  1.75    Male     No   Sat  Dinner     2
#  243       18.78  3.00  Female     No  Thur  Dinner     2
#
#  [130 rows x 7 columns]]

# %%
tips[((tips['total_bill']>10) & (tips['total_bill']<20))]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [130 rows x 7 columns]

# %%
tips1=tips[((tips['total_bill']>10) & (tips['total_bill']<20))] # between 10 and 20 total_bill 
#tips1['tip'].max() :=4.3    #here the heighest total_bill in b/w 10 to 20
tips1[tips1['tip']==tips1['tip'].max()]['sex']   #here 10 to 20 b/w max () tip in sex
# Out:
# 93    Female
# Name: sex, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
sns.catplot(data=tips1,kind='bar',x='sex',y='tip');

# %%
sns.catplot(data=tips1,kind='bar',x='sex',y='tip',hue='tip');

# %%
sns.catplot(data=tips1,kind='bar',x='sex',y='tip',hue='sex');
'''
#here the data and which kind of data(means graph like line or bar) ,x axis ,y axis,hue:this parameter take 
column name for colour encoding;there is a natural order hues like red,yellow,blue,perple. 
'''
# Out:
# '\n#here the data and which kind of data(means graph like line or bar) ,x axis ,y axis,hue:this parameter take \ncolumn name for colour encoding;there is a natural order hues like red,yellow,blue,perple. \n'

# %% [markdown]
# # Q:
#     7Q:Betweem table size 2 and 4, which one has preferred very often?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_7=tips[((tips['size']==2)| (tips['size']==4))]['size'].mode()
tips_7
tips[tips['size']==2]['size'].mode() #:=0    2
tips[tips['size']==4]['size'].mode()  # :=0  4
'''
size 2 is preferred by 157 people and table size 4 priferred by 37 people, that's y size 2 is preferred has very often
'''
# Out:
# "\nsize 2 is preferred by 157 people and table size 4 priferred by 37 people, that's y size 2 is preferred has very often\n"

# %%
tips[((tips['size']==2)| (tips['size']==4))]['size'].value_counts()
# Out:
# 2    156
# 4     37
# Name: size, dtype: int64

# %% [markdown]
# # Q:
#     8Q:I feel Thursday's has a great sale ? please discuss your critics on this sample dataset

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.day,size=50); #total_bill is x-axis and tip is y axis ,hue is the anether attribute is consider
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Fri_=tips[tips['day']=='Fri']

# %%
len(Fri_)  #:= 19
Fri_
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2
# 99        12.46  1.50    Male     No  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# ...

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby("day")['total_bill'].mean()
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
day_1=tips.groupby("day")['total_bill'].value_counts

# %%
day_1;

# %% [markdown]
# # Q:
#     9Q:what is the highest bill paid by sex female?

# %%
tips[tips['sex']=='Female']   #:= 44.3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips[tips['sex']=='Female']['total_bill'].mean()
# Out:
# 18.056896551724137

# %%
tips[tips['sex']=='Female']['total_bill'].max()
# Out:
# 44.3

# %% [markdown]
# # Q:
#     10Q:how much is the difference of highest bill paid by sex Female and Male ?

# %%
h1=tips[tips['sex']=='Female']['total_bill'].max()  #:= 44.3
h2=tips[tips['sex']=="Male"]['total_bill'].max()    #:= 50.81
print("highest bill paid  by female:",h1)
print("highest bill paid by male:",h2)
print('difference of highest bill paid by sex Female and Male',h2-h1)
# Out:
# highest bill paid  by female: 44.3
# highest bill paid by male: 50.81
# difference of highest bill paid by sex Female and Male 6.510000000000005

# %%
tips[tips['sex']=='Female']['total_bill'].max() -tips[tips['sex']=='Male']['total_bill'].max()
tips[tips['sex']=='Male']['total_bill'].max()- tips[tips['sex']=='Female']['total_bill'].max()
# Out:
# 6.510000000000005

# %% [markdown]
# # Q:
#      12Q:which gender has most smoking habit?please provide percentage difference
#         total mumbers are 244:=157 males and 87 female ----->no_smokers 151,smokers 93,in that gender who are most     smoking habit

# %%
tips_data=tips[tips['sex']=='Female']

# %%
d=tips_data[tips_data['smoker']=='Yes']

# %%
len(d)# 33 smoking females ,54 not smoking female ;total female in df 87
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# ...

# %%
tips_rr=tips[tips['sex']=='Male']   #males are 157 in that smoker attribute.inthat active smokers is 60 
ds=tips_rr[tips_rr['smoker']=='Yes']   # no_smoking goys are 97 ;active smokers in males are 60

# %%
#:= active smokers in male 60 ;in that tips dataframe active smokers are 93 i.e active mlae 60 and act female 33
len(ds)
# Out:
# 60

# %%
'''
active smoker females are 33 
total active smokers in df 93
'''
print('active smoker females:',33/93*100) 
print('inactive smoker females:',54/151*100)
# Out:
# active smoker females: 35.483870967741936
# inactive smoker females: 35.76158940397351

# %%
tips_data=tips[tips['sex']=='Female']
d=(len(tips_data[tips_data['smoker']=='Yes'])/len(tips[tips['smoker']=='Yes']))*100
d
# Out:
# 35.483870967741936

# %%
60/93*100
# Out:
# 64.51612903225806

# %%
tips_q=tips[tips['sex']=='Male']
da=(len(tips_q[tips_q['smoker']=='Yes'])/len(tips[tips['smoker']=='Yes']))*100
da
# Out:
# 64.51612903225806

# %%
g=tips[tips['smoker']=='Yes']
len(g)
# Out:
# 93

# %%
sns.countplot(x='sex',data=tips,hue='smoker');

# %%
sns.countplot(x='sex',data=tips,color='black',hue='sex');

# %%
sns.countplot(x='sex',data=tips,color='blue',hue='tip');

# %% [markdown]
# # Q:
#      13Q:which day has lowest sale value?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_=tips[['total_bill','day']].min()
tips_.value_counts()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/2383609673.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tips_=tips[['total_bill','day']].min()
# 3.07    1
# dtype: int64

# %%
plt.figure(figsize=(6,5))
ax=sns.scatterplot(tips.total_bill,tips.tip,hue=tips.day,size=500);
ax.set_title("the sale value",size=20)
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'the sale value')

# %% [markdown]
# # Q:
#     14Q:what are the infrequent total bill value in the dataset?

# %%
sns.boxplot(y=tips['total_bill'],color='red');  # min value of total_bill 3.07
'''
median value of this box actually contain the 50% of the data and from the lower viscosity
it actually contain 25% of data from the the lower respect to the data
'''
# Out:
# '\nmedian value of this box actually contain the 50% of the data and from the lower viscosity\nit actually contain 25% of data from the the lower respect to the data\n'

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ##    boxplot are used when a discrete variable is plotted against a continous variable
#     (find the outliers in the data)

# %%
tips['total_bill'].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
tips['total_bill'].value_counts()   
tips[tips['day']=='Fri'][['sex','time']].value_counts()
# Out:
# sex     time
# Male    Dinner    7
# Female  Dinner    5
#         Lunch     4
# Male    Lunch     3
# dtype: int64

# %%
tips['total_bill'].value_counts()
tips[tips['day']=='Sun'][['sex','tip','time']].value_counts()#.mean()
# Out:
# sex     tip   time
# Male    2.00  Dinner    9
#         3.00  Dinner    4
# Female  3.50  Dinner    4
# Male    5.00  Dinner    3
#         3.50  Dinner    3
#         2.50  Dinner    3
#         4.00  Dinner    3
# Female  4.00  Dinner    2
#         3.61  Dinner    1
# Male    6.00  Dinner    1
#         4.50  Dinner    1
#         4.71  Dinner    1
# Female  5.14  Dinner    1
# Male    5.07  Dinner    1
#         5.15  Dinner    1
# Female  5.00  Dinner    1
# Male    5.60  Dinner    1
#         5.65  Dinner    1
#         6.50  Dinner    1
# Female  3.75  Dinner    1
#         1.01  Dinner    1
#         1.67  Dinner    1
#         2.00  Dinner    1
# Male    4.34  Dinner    1
# Female  2.60  Dinner    1
#         2.61  Dinner    1
#         3.00  Dinner    1
#         3.02  Dinner    1
# Male    1.32  Dinner    1
#         3.71  Dinner    1
#         3.92  Dinner    1
#         2.74  Dinner    1
#         1.56  Dinner    1
#         1.57  Dinner    1
# ...

# %%
tips['total_bill'].value_counts()
tips[tips['day']=='Sun'][['sex','tip','time']].value_counts().mean()
# Out:
# 1.4339622641509433

# %%
tips[tips['day']=='Thur'][['sex','time']].value_counts()
# Out:
# sex     time
# Female  Lunch     31
# Male    Lunch     30
# Female  Dinner     1
# dtype: int64

# %%
tips[tips['day']=='Sat'][['sex','time']].value_counts()
# Out:
# sex     time
# Male    Dinner    59
# Female  Dinner    28
# dtype: int64

# %%
tips[tips['day']=='Sun'][['sex','time']].value_counts()
# Out:
# sex     time
# Male    Dinner    58
# Female  Dinner    18
# dtype: int64

# %%
fig=plt.figure(figsize=(10,8))
axes1=fig.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Male']['total_bill'],tips[tips['sex']=='Female']['total_bill']],
              labels=['Male','Female'])
axes1.set_xlabel("set")
axes1.set_ylabel("Total Bill")
axes1.set_title("Boxplot of Total Bill by sex");

# %% [markdown]
#  # Q:
#      15Q:with respect to Dinner time with table size 3, who has made highest Total bill value when they are smoker ?

# %%
tips_sh=tips[tips['size']==3]['total_bill'].max()
tips_sh
# Out:
# 50.81

# %%
tips[tips['time']=='Dinner'][tips['smoker']=='Yes'][tips['size']==3][tips['total_bill']==tips['total_bill'].max()]['sex']
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/3764416153.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tips[tips['time']=='Dinner'][tips['smoker']=='Yes'][tips['size']==3][tips['total_bill']==tips['total_bill'].max()]['sex']
# 170    Male
# Name: sex, dtype: category
# Categories (2, object): ['Male', 'Female']

# %% [markdown]
# # Q:
#       21Q:During saturday's and Sunday's ,which gender has received highest average value with respect to Lunch and Dinner.
#       average = Total Sum of All Numbers /Number of items in the set

# %%
tips    #28.4549473 female avg ;29.2159694 male avg
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [87 rows x 7 columns]

# %%
tips_sun=tips[tips['day']=='Sun']
tips_sun[tips_sun['sex']=='Female'].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/3796092017.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tips_sun[tips_sun['sex']=='Female'].mean()
# total_bill    19.872222
# tip            3.367222
# size           2.944444
# dtype: float64

# %%
tips_sun=tips[tips['day']=='Sun']
tips_sun[tips_sun['sex']=='Male'].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/171218077.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   tips_sun[tips_sun['sex']=='Male'].mean()
# total_bill    21.887241
# tip            3.220345
# size           2.810345
# dtype: float64

# %%
tips_xy=tips[tips['day']=='Sat']
tips_x=tips_xy[tips_xy['sex']=='Female']
tips_1=tips_x['total_bill'].mean()
tips_1
# Out:
# 19.680357142857137

# %%
'''# total_bill    19.872222
     tip            3.367222
     size           2.944444
dtype: float64    female sunday avarage are given above()'''
tips_sun=tips[tips['day']=='Sun']    #here we consider the sundays with respect to females 
tips_sun[tips_sun['sex']=='Female']#.mean()  
tips_2=tips_sun['total_bill'].mean()   # the average of total_bill of a female data 
tips_2
# Out:
# 21.410000000000004

# %%
tips_1+tips_2/87*100
# Out:
# 44.28955254515599

# %%
total1=tips_1+tips_2/len(tips['sex']=='Female')*100   # sum of  observation by number of observation
total1
# Out:
# 28.454947306791563

# %%
tips[tips['day']=='Sat'][['sex','time']].value_counts()  # saturday female value_count
# Out:
# sex     time
# Male    Dinner    59
# Female  Dinner    28
# dtype: int64

# %%
tips[tips['day']=='Sun'][['sex','time']].value_counts()
# Out:
# sex     time
# Male    Dinner    58
# Female  Dinner    18
# dtype: int64

# %%
t=tips[tips['sex']=='Female']
len(t)
# Out:
# 87

# %%
tips_w=tips[tips['day']=='Sat']
tips_w[tips_w['sex']=='Male'] #.mean()  # here consider the total_bill avg ,tip,size avgs
t_1=tips_w['total_bill'].mean()
t_1
# Out:
# 20.441379310344825

# %%
tips_w=tips[tips['day']=='Sun']
tips_w[tips_w['sex']=='Male']
t_2=tips_w['total_bill'].mean()
t_2
# Out:
# 21.410000000000004

# %%
total=t_1+t_2/len(tips['sex']=='Male')*100

# %%
total
# Out:
# 29.21596947427925

# %%
total=t_1+t_2/len(tips['sex']=='Male')*100
total1=tips_1+tips_2/len(tips['sex']=='Female')*100   # sum of  observation by number of observation
#total1
fig=plt.figure(figsize=(5,5))#fig=plt.figure()
axes1=fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'],color='black')   #=='Male',color='black')
axes1.set_title("dataframe")
plt.plot(total,total1)
plt.xlabel("total")
plt.ylabel("total1")
# Out:
# Text(0, 0.5, 'total1')

# %% [markdown]
# # Q:
#      11Q:which gender has offered a best tip when his/her total bill amount is less than 20$ dollers.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_8=tips[tips['total_bill']<20][['tip']].max() #.mode()  # max tip is 5.15
tips_8
# Out:
# tip    5.15
# dtype: float64

# %%
tips9=tips[tips['total_bill']<20]
tips9[tips9['tip']==tips9['tip'].max()]['sex'].value_counts()
# Out:
# Male      1
# Female    0
# Name: sex, dtype: int64

# %%
tips9=tips[tips['total_bill']<20]
tips9[tips9['tip']==tips9['tip'].max()]['sex']     #.value_counts()
# Out:
# 172    Male
# Name: sex, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
tips9[tips9['tip']==tips9['tip'].max()]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2

# %% [markdown]
# # Q:
#      18.When compared to Saturday's and Sunday's, Which day has highest sale? and show both days distribution in single histogram
#      Saturday is the highest sale.

# %%
tips_st=tips[tips['day']=='Sat']['total_bill']
tips_sn=tips[tips['day']=='Sun']['total_bill']
tips_st.max()
# Out:
# 50.81

# %%
len(tips_sn)
# Out:
# 76

# %%
fig=plt.figure(figsize=(6,8))
axes1=fig.add_subplot(1,1,1)
axes1.hist([tips_st,tips_sn],color=['blue','yellow'],label=['Saturday','Sunday'])
axes1.legend();

# %% [markdown]
# # Q:
#       25.Why do you feel Sunday's total bill distribution is slightly higher than other days? show plot and discuss

# %%
sns.countplot('day',data=tips,color='brown');
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips[tips['day']=='Sun']['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: total_bill, Length: 76, dtype: float64

# %%
tips_di=tips[tips['day']=='Sun']['total_bill']
tips_di
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: total_bill, Length: 76, dtype: float64

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_sun=tips[tips['day']=='Sun']['total_bill']
tips_sun
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: total_bill, Length: 76, dtype: float64

# %%
tips_sat=tips[tips['day']=='Sat']['total_bill']
tips_sat
# Out:
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
#        ...
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# Name: total_bill, Length: 87, dtype: float64

# %%
tips_thur=tips[tips['day']=='Thur']['total_bill']
tips_thur
# Out:
# 77     27.20
# 78     22.76
# 79     17.29
# 80     19.44
# 81     16.66
#        ...
# 202    13.00
# 203    16.40
# 204    20.53
# 205    16.47
# 243    18.78
# Name: total_bill, Length: 62, dtype: float64

# %%
tips_fri=tips[tips['day']=='Fri']['total_bill']
tips_fri
# Out:
# 90     28.97
# 91     22.49
# 92      5.75
# 93     16.32
# 94     22.75
# 95     40.17
# 96     27.28
# 97     12.03
# 98     21.01
# 99     12.46
# 100    11.35
# 101    15.38
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# Name: total_bill, dtype: float64

# %%
tips_sun=tips[tips['day']=='Sun']['total_bill']#.mean()
tips_sat=tips[tips['day']=='Sat']['total_bill']#.mean()
tips_thur=tips[tips['day']=='Thur']['total_bill']#.mean() #.max()
tips_fri=tips[tips['day']=='Fri']['total_bill']#.mean()  #.max()

print("sunday total bill",tips_sun.mean())
print("satur day avg of total bill",tips_sat.mean())
print("thurday max value in total bill",tips_thur.mean())
print("fri day max value in total value:",tips_fri.mean())

fig=plt.figure(figsize=(10,8))
axes1=fig.add_subplot(1,1,1)
axes1.hist([tips_sun,tips_sat,tips_thur,tips_fri],color=['orchid','fuchsia','aquamarine','sienna'],label=['sunday','saturday','thursday','friday'])
axes1.set_xlabel("total bill")
axes1.set_ylabel("tip")
axes1.legend();
# Out:
# sunday total bill 21.410000000000004
# satur day avg of total bill 20.441379310344825
# thurday max value in total bill 17.682741935483865
# fri day max value in total value: 17.151578947368417

# %% [markdown]
# # Q:
#         23.Did you observed any pattern observations of tip variable from this dataset?

# %%
x1=tips['tip'] 
fig = plt.figure(figsize=(5,5))
axes1=fig.add_subplot(1,1,1)
axes1.hist([x1],color='teal',label='tips')
axes1.legend();

# %% [markdown]
# # Q:
#      24. Find the Gender for max tip with minimum total bill value and min tip with max total bill value

# %% [markdown]
# '''
# here find the gender for max tip with max total bill value and min tip with min total bill value is correct way
# I wiil paid total bill is high then i will give high tip ,low amount is low tip to give
# '''

# %%
tips['tip'].max()
# Out:
# 10.0

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(tips.total_bill,tips.total_bill);

# %%
sns.scatterplot(tips.total_bill,tips.tip); #scatterplot function used from the seaborn library. total_bill is x-axis,y-axis is tip
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.time,s=50); #scatterplot function used from the seaborn library. 
#total_bill is x-axis,y-axis is tip;hue is the anether series is added; size is 50
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.day,s=100);
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.title("tips data")
sns.scatterplot(tips['sex']=='Female',tips.smoker,hue=tips.day,s=99)
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'tips data'}, xlabel='sex', ylabel='smoker'>

# %% [markdown]
# # Histogram
#    A Histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.
#     hostogram is a single type of variable. reprensent in bars

# %%
tips.total_bill #.min() 3.07 #.max()50.81
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips.tip #.mean() is 2.9982786885245902   #.min()is 1.0  #.max() 10.0
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
fig=plt.figure(figsize=(10,8))
axes1=fig.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Male']['total_bill'],tips[tips['sex']=='Female']['total_bill']],
              labels=['Male','Female'])
axes1.set_xlabel("set")
# Out:
# Text(0.5, 0, 'set')

# %%
tips.describe()  #each numeric column it tells the bunch of statistic data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.title("distribution of total_bill ")
plt.hist(tips.total_bill,color='green');

# %%
plt.title("distribution of total_bill ")
plt.hist(tips.total_bill,color='green',bins=5);

# %%
import numpy as np
np.arange(2,5,0.25) #starting with 2 upto 5, range is 0.25.2+0.25.....<5
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
import numpy as np
plt.hist(tips.total_bill,bins=np.arange(2,5,0.25));

# %%
plt.hist(tips.total_bill,bins=np.arange(50.81));#here the range is 0 to 50 in x-axis
plt.xlabel("total_biil")
plt.ylabel("tips")
# Out:
# Text(0, 0.5, 'tips')

# %% [markdown]
# # Q:
#       5. Which time of restaurant visit is mostly preferred by customers?
#         Ans:  dinner time mostly preferred for customer i.e 176 (are Dinner time)
#        Lunch is 68

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sns.scatterplot(tips.total_bill,tips.tip);
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.time,s=99);
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# # Q:
#        6. Do you think Friday's has received highest sale when compared to other days?

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.day,s=100);   # to add  the total_bill,tip are x,y axis then we add day .
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips.day.value_counts()  #friday is the lowest sale to compare to the other days
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# # Q:
#       7. Between table sizes 2 & 4, which one has preferred very often?
#        dinner we are preterred

# %%
tips['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
tips[tips['size']==2].value_counts()
# Out:
# total_bill  tip   sex     smoker  day   time    size
# 13.00       2.00  Female  Yes     Thur  Lunch   2       2
# 18.24       3.76  Male    No      Sat   Dinner  2       1
# 17.51       3.00  Female  Yes     Sun   Dinner  2       1
# 17.78       3.27  Male    No      Sat   Dinner  2       1
# 17.82       1.75  Male    No      Sat   Dinner  2       1
#                                                        ..
# 13.28       2.72  Male    No      Sat   Dinner  2       1
# 13.37       2.00  Male    No      Sat   Dinner  2       1
# 13.39       2.61  Female  No      Sun   Dinner  2       1
# 13.42       1.58  Male    Yes     Fri   Lunch   2       1
# 40.55       3.00  Male    Yes     Sun   Dinner  2       1
# Length: 155, dtype: int64

# %%
tips[tips['size']==4].value_counts()
# Out:
# total_bill  tip   sex     smoker  day   time    size
# 16.49       2.00  Male    No      Sun   Dinner  4       1
# 26.88       3.12  Male    No      Sun   Dinner  4       1
# 29.93       5.07  Male    No      Sun   Dinner  4       1
# 30.14       3.09  Female  Yes     Sat   Dinner  4       1
# 30.40       5.60  Male    No      Sun   Dinner  4       1
# 31.71       4.50  Male    No      Sun   Dinner  4       1
# 32.40       6.00  Male    No      Sun   Dinner  4       1
# 34.65       3.68  Male    Yes     Sun   Dinner  4       1
# 34.81       5.20  Female  No      Sun   Dinner  4       1
# 34.83       5.17  Female  No      Thur  Lunch   4       1
# 35.26       5.00  Female  No      Sun   Dinner  4       1
# 38.01       3.00  Male    Yes     Sat   Dinner  4       1
# 38.73       3.00  Male    Yes     Sat   Dinner  4       1
# 39.42       7.58  Male    No      Sat   Dinner  4       1
# 40.17       4.73  Male    Yes     Fri   Dinner  4       1
# ...

# %% [markdown]
# # Q:
#       8. I feel Thursday's has a great sale? Please discuss your critics on this sample dataset.

# %%
sns.scatterplot(tips.total_bill,tips.tip,hue=tips.day,s=100);
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# # Q:
#        39. Which day is more preferred for lunch by female group?
#        Thursday Females are more preferred for Lunch (38)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['time']=='Lunch']
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1
# 223       15.98  3.00  Female     No   Fri  Lunch     3
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2
#
# [68 rows x 7 columns]

# %%
tips_sex=tips[tips['sex']=='Female']
tips_M=tips_sex[tips_sex['time']=='Lunch']
tips_M
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 82        10.07  1.83  Female     No  Thur  Lunch     1
# 85        34.83  5.17  Female     No  Thur  Lunch     4
# 117       10.65  1.50  Female     No  Thur  Lunch     2
# 118       12.43  1.80  Female     No  Thur  Lunch     2
# 119       24.08  2.92  Female     No  Thur  Lunch     4
# 121       13.42  1.68  Female     No  Thur  Lunch     2
# 124       12.48  2.52  Female     No  Thur  Lunch     2
# 125       29.80  4.20  Female     No  Thur  Lunch     6
# 127       14.52  2.00  Female     No  Thur  Lunch     2
# 128       11.38  2.00  Female     No  Thur  Lunch     2
# 131       20.27  2.83  Female     No  Thur  Lunch     2
# 132       11.17  1.50  Female     No  Thur  Lunch     2
# 133       12.26  2.00  Female     No  Thur  Lunch     2
# 134       18.26  3.25  Female     No  Thur  Lunch     2
# 135        8.51  1.25  Female     No  Thur  Lunch     2
# 136       10.33  2.00  Female     No  Thur  Lunch     2
# ...

# %%
len(tips_M)
# Out:
# 35

# %%
tips_sex=tips[tips['sex']=='Female']# here Female data is taken in sex series/attribute
tips_sex[tips_sex['time']=='Lunch'].value_counts()  # in that size 2 is more preferred;here mostly females  lunch prefrred by Thurday
# Out:
# total_bill  tip   sex     smoker  day   time   size
# 13.00       2.00  Female  Yes     Thur  Lunch  2       2
# 8.35        1.50  Female  No      Thur  Lunch  2       1
# 18.26       3.25  Female  No      Thur  Lunch  2       1
# 16.27       2.50  Female  Yes     Fri   Lunch  2       1
# 16.40       2.50  Female  Yes     Thur  Lunch  2       1
# 16.43       2.30  Female  No      Thur  Lunch  2       1
# 16.47       3.23  Female  Yes     Thur  Lunch  3       1
# 17.47       3.50  Female  No      Thur  Lunch  2       1
# 18.64       1.36  Female  No      Thur  Lunch  3       1
# 14.52       2.00  Female  No      Thur  Lunch  2       1
# 19.81       4.19  Female  Yes     Thur  Lunch  2       1
# 20.27       2.83  Female  No      Thur  Lunch  2       1
# 24.08       2.92  Female  No      Thur  Lunch  4       1
# 27.05       5.00  Female  No      Thur  Lunch  6       1
# 29.80       4.20  Female  No      Thur  Lunch  6       1
# 34.83       5.17  Female  No      Thur  Lunch  4       1
# ...

# %% [markdown]
# # Q:
#       38. Which day is more preferred for lunch time?

# %%
tip_d=tips[tips['time']=='Lunch']
tip_d['day']
# Out:
# 77     Thur
# 78     Thur
# 79     Thur
# 80     Thur
# 81     Thur
#        ...
# 222     Fri
# 223     Fri
# 224     Fri
# 225     Fri
# 226     Fri
# Name: day, Length: 68, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.scatterplot(tips.time,tips.day); # here Lunch is most prefrred as Thursday ,Fri day
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Q:
#    20Q: Who loves smoking mostly and does that affect tip values when compared to non-smoking customers
#       93 are not smoking in data include all,151 are smoking.in that not smokking is female andmale

# %%
tips.groupby(['smoker'])['tip'].mean()  # to describe the  total data
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
sns.boxplot(y=tips['tip'],x=tips['sex'],hue=tips['smoker'],color='brown');

# %% [markdown]
# # Q:
#      22. Do you think "smoker" variable is more influenced by gender?

# %%
#gender is more effected by "smoker" variable# gender is influenced by smoker variable

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %% [markdown]
# # Q:
#        23. Did you observed any pattern observations of tip variable from this dataset?

# %%
tips['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['tip']
sns.scatterplot(tips.tip,tips.tip);
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Q:
#      26. Take "sex" variable separately and covert into list. And define a function to encode "Female" as 1 and "Male" has 0.

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
(tips.sex)
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
# listd=tips['tip']
# list=list[listd[listd]]
# list
list=tips['tip']
list#.value_counts()
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tip=tips['sex']
tip[tips['sex']=='Female']
# d=list[tip]
# print(d)
for each in tip:
    each=0;
    if each==True and each ==False:
        print("female:")
    else:
        print("male")
# Out:
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# male
# ...

# %%
# list=tips.sex
# listd=list
# listd
tips.sex=='Female'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
#tipd=tips[tips['sex']=='Female']
list=tips.sex
listd=list
def encode_(listd):
    if tips.sex=='Female':
        return 1;
    else:
        return 0;

#tips['sex_code01']=tips['sex'].apply(encode_)

# %%
def emcode_(sex):
    if sex=='Female':
        return 1;
    else:
        return 0;

# %%
tips["sex_code"]=tips['sex'].apply(emcode_)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1
#
# [244 rows x 8 columns]

# %%
listd=tips.sex_code
list[listd]
# Out:
# 1      Male
# 0    Female
# 0    Female
# 0    Female
# 1      Male
#       ...
# 0    Female
# 1      Male
# 0    Female
# 0    Female
# 1      Male
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
tips['tip'].min()
# Out:
# 1.0

# %% [markdown]
# # Q:
#        27. How do you add new column to this dataset?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1
#
# [244 rows x 8 columns]

# %%
new_tips=tips['total_bill']
new_tips
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
#tips["sex_code"]=tips['sex'].apply(encode_)
tips["sex_column"]=tips['sex'].apply(emcode_)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
# [244 rows x 9 columns]

# %%
tips['total_col']=tips['total_bill'].max()# add a new column/attribute  to the given tips data
tips['tips_high']=tips['tip'].max()
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
#      total_col  tips_high
# ...

# %% [markdown]
# # Q:
#       28. How do you drop a new column that was created in last question?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
#      total_col  tips_high
# ...

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips['sex'].drop
# Out:
# <bound method Series.drop of 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']>

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
#  7   sex_code    244 non-null    category
#  8   sex_column  244 non-null    category
#  9   total_col   244 non-null    float64
#  10  tips_high   244 non-null    float64
# dtypes: category(6), float64(4), int64(1)
# memory usage: 11.9 KB

# %%
#tips.drop(['sex_code'],axis=1,inplace=True)
#tips.drop(tips['sex_code'],axis=1,inplace=True)
#tips.columns

# %% [markdown]
# # Q:
#       29. Show the total bill averages of different days in the data? and plot the same data

# %%
tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
tips.groupby("day")["total_bill"].mean()
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
sns.displot(data=tips,x='total_bill',col='day',kde=True);

# %% [markdown]
# # #@
#    40. Please explain the significance role of Scatter plot?
#       A scatter plot is a set of points on a horizontal and vertical axes.scatter plots are useful data visualization tools for illustrating a trend.
#       A scatter plot is a set of point plotted on a horizontal and vertical(y-axis) axes.

# %% [markdown]
#       # 16. What is meant by Spurious data analysis?
#       # 17. Why Correlation doesn't imply causation? Give at least TWO examples on this.
#       # 19. Do you think when table size is increased we receive higher total bills and tip values?
#       # 20. Who loves smoking mostly and does that affect tip values when compared to non-smoking customers?

# %% [markdown]
# # 16Q. What is meant by Spurious data analysis?
#        spurious correlation can be caused by small sample values or orbitary
#        A spurious correlation(or spuriousness)refers to a connection between variable that appears to be causal but it not with spurious observed dependencies between variable are merely due to chance or are both related to some unseen confounder.
#        connection between two variable; spurious data analysis meant by describe a statistical relationship between two variables
#
#
#   What are examples of spurious correlations?
#
#
#
#   spurious correlation:- significant Correlation b/w two events or varibles,having no casual connection
#   Due to coincidence or any third or unseen factor
#       #########careful interpreting Correlation -Correlation b/w number of police men effective an area,patrolling an area  and the number of crimes happening.Doesn't mean more than police is the crime rate.

# %% [markdown]
#       # ######.describe a statistical relationship between two variables

# %% [markdown]
# # Q:
#     17. Why Correlation doesn't imply causation? Give at least TWO examples on this.
#    correlation means that,it is  the relationship between two variable.
#    causation means it not effect to the other it means that Correlation is not causation" means that just because two things correlate does not necessarily mean that one causes the other
#
#    eg:windspeed ,windmil speed
#   "Causation" means that one variable causes another to change, which means one variable is dependent on the other. It is also called cause and effect. One example would be as weather gets hot, people experience more sunburns. In this case, the weather caused an effect which is sunburn.
#   student is depend on teacher but dosen't teacher depends on students.
#
#   A positive "correlation" exists when two variables move in the same direction as one another. A basic example of positive correlation is height and weight—taller people tend to be heavier, and vice versa. ... A positive correlation can be seen between the demand for a product and the product's associated price.

# %% [raw]
# # Q:
#    19. Do you think when table size is increased we receive higher total bills and tip values?

# %%
tips.groupby("size")['total_bill',"tip"].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/1572666852.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tips.groupby("size")['total_bill',"tip"].mean()
#       total_bill       tip
# size
# 1       7.242500  1.437500
# 2      16.448013  2.582308
# 3      23.277632  3.393158
# 4      28.613514  4.135405
# 5      30.068000  4.028000
# 6      34.830000  5.225000

# %% [markdown]
# # Q:
#    30. What is meant by broadcasting the data?
#
#            Data broadcasting is the system that the receiving device automatically decodes and receiver directly gets the decoding data in the case of transmitting digital signal through broadcasting wave.
#            To broadcast is to transmit information to a lot of people, especially when done via television or radio.
#            When you tell everyone in the neighborhood some news, this is an example of a time when you broadcast the news.

# %% [markdown]
# # Q:
#    31. What is meant by Scalar operation? and show a example.

# %% [markdown]
#      When we add, subtract, multiply or divide a matrix by a number, this is called the scalar operation. Scalar operations produce a new matrix with same number of rows and columns with each element of the original matrix added to, subtracted from, multiplied by or divided by the number.
#       scalar, a physical quantity that is completely described by its magnitude; examples of scalars are volume, density, speed, energy, mass, and time. Other quantities, such as force and velocity, have both magnitude and direction and are called vectors.

# %%
tips['total_bill']/10+tips['tip']/2
(tips['total_bill']+tips['tip'])/10
# Out:
# 0      1.800
# 1      1.200
# 2      2.451
# 3      2.699
# 4      2.820
#        ...
# 239    3.495
# 240    2.918
# 241    2.467
# 242    1.957
# 243    2.178
# Length: 244, dtype: float64

# %% [markdown]
# # Q:
#      32. Group the data based on "sex" variable and find their respective averages and plot the same.

# %%
tips['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']

# %%
tips.groupby('sex')['total_bill','tip'].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/1959609288.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tips.groupby('sex')['total_bill','tip'].mean()
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
tip=tips.groupby('sex')['total_bill','tip']
tip.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10648/1186717936.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tip=tips.groupby('sex')['total_bill','tip']
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
tips.groupby('sex')['tip'].value_counts()
# Out:
# sex     tip
# Male    2.00    22
#         3.00    16
#         4.00     9
#         5.00     6
#         1.50     5
#                 ..
# Female  4.67     1
#         5.14     1
#         5.17     1
#         5.20     1
#         6.50     1
# Name: tip, Length: 139, dtype: int64

# %%
tips.groupby('sex')['total_bill'].value_counts()
# Out:
# sex     total_bill
# Male    10.34         2
#         13.81         2
#         15.69         2
#         17.92         2
#         18.29         2
#                      ..
# Female  34.83         1
#         35.26         1
#         35.83         1
#         43.11         1
#         44.30         1
# Name: total_bill, Length: 235, dtype: int64

# %%
# tips.groupby('sex')['total_bill'].value_counts()
# tips.groupby('sex')['tip'].value_counts()
tips.groupby('sex')['total_bill'].value_counts()  & tips.groupby('sex')['tip'].value_counts()
# Out:
# sex     total_bill  tip
# Male    10.34       2.00     True
#                     3.00    False
#                     4.00    False
#                     5.00     True
#                     1.50    False
#                             ...
# Female  44.30       4.67     True
#                     5.14     True
#                     5.17     True
#                     5.20     True
#                     6.50     True
# Length: 17706, dtype: bool

# %%
tips.groupby('sex')['total_bill'].mean().value_counts()  & tips.groupby('sex')['tip'].mean().value_counts()
# Out:
# 2.833448     False
# 3.089618     False
# 18.056897    False
# 20.744076    False
# dtype: bool

# %% [markdown]
#  # Q:
#      33. How do you determine if two variables are highly or lowly correlated?

# %%
plt.plot(tips[['total_bill','tip']])#,label=['total_bill','tip']);
plt.xlabel("total bill")
plt.ylabel("tip")
plt.legend(['total bill','tip']);

# %% [markdown]
# # Q:
#      34. What table is chosen When total_bill value is exactly $13.42 dollars and gender is female.

# %%
tips_gend=tips[tips['total_bill']==13.42]
tips_gend[tips_gend['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day   time  size sex_code sex_column  \
# 121       13.42  1.68  Female     No  Thur  Lunch     2        1          1
# 221       13.42  3.48  Female    Yes   Fri  Lunch     2        1          1
#
#      total_col  tips_high
# 121      50.81       10.0
# 221      50.81       10.0

# %% [markdown]
# # Q:
#       35. What is the mostly preferred time when table size is 5?

# %%
tips_t=tips[tips['size']==5]
#tips_t['time'] # mostly prefered time is Dinner (in that males are high to preferred for Dinner)
tips_t
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 142       41.19  5.00    Male     No  Thur   Lunch     5        0          0
# 155       29.85  5.14  Female     No   Sun  Dinner     5        1          1
# 185       20.69  5.00    Male     No   Sun  Dinner     5        0          0
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5        0          0
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5        0          0
#
#      total_col  tips_high
# 142      50.81       10.0
# 155      50.81       10.0
# 185      50.81       10.0
# 187      50.81       10.0
# 216      50.81       10.0

# %% [markdown]
#  # Q:
#      36. Which day is mostly preferred when table size is 4?

# %%
tips[(tips['size']==4) & (tips['day']=='Sun')].value_counts()
# Out:
# total_bill  tip   sex     smoker  day  time    size  sex_code  sex_column  total_col  tips_high
# 16.49       2.00  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# 18.43       3.00  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# 34.81       5.20  Female  No      Sun  Dinner  4     1         1           50.81      10.0         1
# 34.65       3.68  Male    Yes     Sun  Dinner  4     0         0           50.81      10.0         1
# 32.40       6.00  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# 31.71       4.50  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# 30.40       5.60  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# 29.93       5.07  Male    No      Sun  Dinner  4     0         0           50.81      10.0         1
# ...

# %%
tips[tips['size']==4]['day'].value_counts()
# Out:
# Sun     18
# Sat     13
# Thur     5
# Fri      1
# Name: day, dtype: int64

# %%
tips[tips['size']==4]['day'].mode() # mostly preferred Sun day in size 4
# Out:
# 0    Sun
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# # Q:
#     37. When it's Saturday's, which two table sizes are mostly preferred?

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
#      total_col  tips_high
# ...

# %%
tips[tips['day']=='Sat']#here Saturday details #['size']#.value_counts()
# Out:
#      total_bill   tip     sex smoker  day    time  size sex_code sex_column  \
# 19        20.65  3.35    Male     No  Sat  Dinner     3        0          0
# 20        17.92  4.08    Male     No  Sat  Dinner     2        0          0
# 21        20.29  2.75  Female     No  Sat  Dinner     2        1          1
# 22        15.77  2.23  Female     No  Sat  Dinner     2        1          1
# 23        39.42  7.58    Male     No  Sat  Dinner     4        0          0
# ..          ...   ...     ...    ...  ...     ...   ...      ...        ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3        1          1
# 239       29.03  5.92    Male     No  Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No  Sat  Dinner     2        0          0
#
#      total_col  tips_high
# 19       50.81       10.0
# ...

# %%
tips[tips['day']=='Sat']['size'].value_counts()   # Saturday with there sizes;size 2 is 53 numbers and size 3 is 18..
# Out:
# 2    53
# 3    18
# 4    13
# 1     2
# 5     1
# Name: size, dtype: int64

# %%
len(tips[tips['day']=='Sat'])
# Out:
# 87

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
#      total_col  tips_high
# ...

# %%
#the counts of observations in each categorical bin using bars.
#A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.func barplot to easy manner
plt.figure(figsize=(10,8))
tips_data=sns.countplot('day',x=5,data=tips,color="goldenrod",hue='time');
sns.color_palette("Paired")
tips_data.set_title("Count of the day",size=15)
# Out:
# C:\Users\Admin\anaconda3\DLLs\mysite\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Count of the day')

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg"); #kind=hex,reg,scatter,kd

# %%
sns.barplot(x="time",y="total_bill",data=tips);

# %%
sns.violinplot(x="time",y="total_bill",data=tips,s=50);

# %%
sns.pairplot(tips);

# %%
sns.heatmap(tips.corr());

# %%
tips[tips.corr()]
# Out:
#      total_bill  tip  sex smoker  day time  size sex_code sex_column  \
# 0           NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 1           NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 2           NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 3           NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 4           NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# ..          ...  ...  ...    ...  ...  ...   ...      ...        ...
# 239         NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 240         NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 241         NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 242         NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
# 243         NaN  NaN  NaN    NaN  NaN  NaN   NaN      NaN        NaN
#
#      total_col  tips_high
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# ...

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_code sex_column  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2        1          1
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0          0
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0          0
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0          0
# 4         24.59  3.61  Female     No   Sun  Dinner     4        1          1
# ..          ...   ...     ...    ...   ...     ...   ...      ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0          0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        1          1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0          0
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0          0
# 243       18.78  3.00  Female     No  Thur  Dinner     2        1          1
#
#      total_col  tips_high
# ...
